# %%
import pandas as pd

# %%
df_cdr = pd.read_csv(r"Z:\AIDAILER\cdr\cdr.csv",warn_bad_lines=True, error_bad_lines=False, engine="python")
# Out:
# C:\Users\trainee10\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\trainee10\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_cdr.columns
# Out:
# Index(['id', 'callid', 'callid_b', 'switch', 'call_time', 'source_ip',
#        'source_number', 'account_id', 'account_card_id', 'reseller_id',
#        'dest_cli', 'tech_prefix', 'dest_number', 'lrn_number', 'jurisdiction',
#        'customer_dest_code', 'reseller_dest_code', 'provider_dest_code',
#        'customer_dest_name', 'reseller_dest_name', 'provider_dest_name',
#        'customer_duration', 'reseller_duration', 'provider_duration',
#        'customer_rate', 'reseller_rate', 'provider_rate', 'duration',
#        'customer_mcd', 'customer_pulse', 'customer_connect_cost',
#        'reseller_mcd', 'reseller_pulse', 'reseller_connect_cost',
#        'provider_mcd', 'provider_pulse', 'provider_connect_cost',
#        'release_reason', 'pdd_in', 'pdd_out', 'ring_duration', 'provider_id',
#        'provider_card_id', 'cost', 'retail', 'reseller', 'cost_currency',
#        'retail_currency', 'reseller_currency', 'status', 'from_tag', 'to_tag',
# ...

# %%
pd.set_option('max_columns', None)

# %%
df_cdr.head()
# Out:
#           id                                             callid  \
# 0  573149379  278c0f951a5815325bc7d46256f37594@148.72.173.23...
# 1  573149463  5b1930cb7140168b6d028df8247512cc@148.72.168.22...
# 2  573149465  07e8922e77d9338a7a90ba1959eb0214@148.72.168.22...
# 3  573149639  15e10157538188f0171ef57c1f4a1667@148.72.168.22...
# 4  573149641  07e8922e77d9338a7a90ba1959eb0214@148.72.168.22...
#
#                                             callid_b          switch  \
# 0  CNX2920_cQdWLQM+ZgcIUwVnchFwAlssUG87Bg8ABWklF3...  159.203.92.196
# 1  CNX3067_dlJfdwBoPFEHBwNvchJ7UlgqA2pnV1YOBWt0EX...   161.35.121.80
# 2  CNX3067_cwcLdgpqbVYHAVNmcBd7UVkvCmg9UgEPAmYmRn...   161.35.121.80
# 3  CNX3067_cgULfwNpagQFBQ9uexwlAF95Aj05BgdVBjl3RX...   161.35.121.80
# 4  CNX3067_cwcLdgpqbVYHAVNmcBd7UVkvCmg9UgEPAmYmRn...   161.35.121.80
#
#                                            call_time       source_ip  \
# 0  Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...   148.72.173.23
# ...

# %%
# formatted_df = df_cdr['call_time'].dt.strftime('%m/%d/%y')
a = list(dfnew['call_time'])

# %%
list1 = dfnew['call_time'].to_list()

# dfnew['call_time'][0][3:25]
date_time =  [i[3:25] for i in list1]

# %%
dfnew[dfnew['call_time'].str.contains(' Feb ')]
# Out:
# Empty DataFrame
# Columns: [id, callid, callid_b, switch, call_time, source_ip, source_number, account_id, account_card_id, reseller_id, dest_cli, tech_prefix, dest_number, lrn_number, jurisdiction, customer_dest_code, reseller_dest_code, provider_dest_code, customer_dest_name, reseller_dest_name, provider_dest_name, customer_duration, reseller_duration, provider_duration, customer_rate, reseller_rate, provider_rate, duration, customer_mcd, customer_pulse, customer_connect_cost, reseller_mcd, reseller_pulse, reseller_connect_cost, provider_mcd, provider_pulse, provider_connect_cost, release_reason, pdd_in, pdd_out, ring_duration, provider_id, provider_card_id, cost, retail, reseller, cost_currency, retail_currency, reseller_currency, status, from_tag, to_tag, sip_code, sip_reason, dtmf, ingress_id, recording_cost, billing_id, failed_routes, rtp_info]
# Index: []

# %%
dfnew['call_time'] = date_time

# %%
d = {'Jan':1,}

# %%
d["Jan"]
# Out:
# 1

# %%
newdf.call_time = newdf.call_time.map(d)

# %%
df_cdr['call_time']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 947278   NaN
# 947279   NaN
# 947280   NaN
# 947281   NaN
# 947282   NaN
# Name: call_time, Length: 947283, dtype: float64

# %%
dfnew1['call_time']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 947278   NaN
# 947279   NaN
# 947280   NaN
# 947281   NaN
# 947282   NaN
# Name: call_time, Length: 947283, dtype: float64

# %%
df_cdr['call_time']
# Out:
# 0         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
# 1         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
# 2         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
# 3         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
# 4         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
#                                 ...
# 947278    Wed Jan 20 2021 15:50:56 GMT+0000 (Coordinated...
# 947279    Wed Jan 20 2021 15:50:56 GMT+0000 (Coordinated...
# 947280    Wed Jan 20 2021 15:50:56 GMT+0000 (Coordinated...
# 947281    Wed Jan 20 2021 15:50:57 GMT+0000 (Coordinated...
# 947282    Wed Jan 20 2021 15:50:58 GMT+0000 (Coordinated...
# Name: call_time, Length: 947283, dtype: object

# %%
 newdf = df_cdr

# %%
newdf.head()
# Out:
#           id                                             callid  \
# 0  573149379  278c0f951a5815325bc7d46256f37594@148.72.173.23...
# 1  573149463  5b1930cb7140168b6d028df8247512cc@148.72.168.22...
# 2  573149465  07e8922e77d9338a7a90ba1959eb0214@148.72.168.22...
# 3  573149639  15e10157538188f0171ef57c1f4a1667@148.72.168.22...
# 4  573149641  07e8922e77d9338a7a90ba1959eb0214@148.72.168.22...
#
#                                             callid_b          switch  \
# 0  CNX2920_cQdWLQM+ZgcIUwVnchFwAlssUG87Bg8ABWklF3...  159.203.92.196
# 1  CNX3067_dlJfdwBoPFEHBwNvchJ7UlgqA2pnV1YOBWt0EX...   161.35.121.80
# 2  CNX3067_cwcLdgpqbVYHAVNmcBd7UVkvCmg9UgEPAmYmRn...   161.35.121.80
# 3  CNX3067_cgULfwNpagQFBQ9uexwlAF95Aj05BgdVBjl3RX...   161.35.121.80
# 4  CNX3067_cwcLdgpqbVYHAVNmcBd7UVkvCmg9UgEPAmYmRn...   161.35.121.80
#
#                                            call_time       source_ip  \
# 0  Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...   148.72.173.23
# ...

# %%
data[] = date_time
# Out:
# [' Jan 18 2021 19:00:00 ',
#  ' Jan 18 2021 19:00:00 ',
#  ' Jan 18 2021 19:00:00 ',
#  ' Jan 18 2021 19:00:00 ',
#  ' Jan 18 2021 19:00:00 ']

# %%
date_format=[]
for i in a:
    i.remove(' GMT+0000 (Coordinated Universal Time)')
    date_format.append(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\TRAINE~1\AppData\Local\Temp/ipykernel_7768/4115140523.py in <module>
#       1 date_format=[]
#       2 for i in a:
# ----> 3     i.remove(' GMT+0000 (Coordinated Universal Time)')
#       4     date_format.append(i)
#
# AttributeError: 'str' object has no attribute 'remove'

# %%
dfnew['call_time'][0][3:25]
# Out:
# ' Jan 18 2021 19:00:00 '

# %%
dfnew['call_time'] =
# Out:
# 0         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
# 1         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
# 2         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
# 3         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
# 4         Mon Jan 18 2021 19:00:00 GMT+0000 (Coordinated...
#                                 ...
# 947278    Wed Jan 20 2021 15:50:56 GMT+0000 (Coordinated...
# 947279    Wed Jan 20 2021 15:50:56 GMT+0000 (Coordinated...
# 947280    Wed Jan 20 2021 15:50:56 GMT+0000 (Coordinated...
# 947281    Wed Jan 20 2021 15:50:57 GMT+0000 (Coordinated...
# 947282    Wed Jan 20 2021 15:50:58 GMT+0000 (Coordinated...
# Name: call_time, Length: 947283, dtype: object

# %%
a.remove([1][0:3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\TRAINE~1\AppData\Local\Temp/ipykernel_7768/3270341742.py in <module>
# ----> 1 a.remove([1][0:3])
#
# ValueError: list.remove(x): x not in list

# %%
df_cdr['call_time']
# Out:
# 0        NaT
# 1        NaT
# 2        NaT
# 3        NaT
# 4        NaT
#           ..
# 947278   NaT
# 947279   NaT
# 947280   NaT
# 947281   NaT
# 947282   NaT
# Name: call_time, Length: 947283, dtype: datetime64[ns]

# %%
dfnew['call_time'] = pd.to_datetime(dfnew['call_time']).dt.strftime('%H:%M')
dfnew
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2186         try:
# -> 2187             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2188             # If tzaware, these values represent unix timestamps, so we
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# C:\Users\TRAINE~1\AppData\Local\Temp/ipykernel_7768/3826775268.py in <module>
# ...

# %%
localtime =dfnew['call_time'].to_list()
hr = [str(t).split(":")[0].split()[-1] for t in localtime]

# %%
# df_cdr['call_time'] = pd.to_datetime(df_cdr["call_time"].dt.strftime('%Y-%m'))
df_cdr['call_time']=pd.to_datetime(df_cdr['call_time'].astype(str), format='%m/%d/%Y %H:%M:%S.%f')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\TRAINE~1\AppData\Local\Temp/ipykernel_7768/3275643853.py in <module>
#       1 # df_cdr['call_time'] = pd.to_datetime(df_cdr["call_time"].dt.strftime('%Y-%m'))
# ...

# %%
type(df_cdr['date'][0])
# Out:
# str

# %%
df_cdr['date'].value_counts()
# Out:
# 2021-01-02 19:33:44    68
# 2021-01-02 18:45:22    68
# 2021-01-02 16:08:57    66
# 2021-01-02 18:53:06    64
# 2021-01-02 19:29:28    63
#                        ..
# 2021-01-02 15:41:23     1
# 2021-01-02 16:27:25     1
# 2021-01-02 17:00:03     1
# 2021-01-02 19:53:13     1
# 2021-01-02 20:24:00     1
# Name: date, Length: 15857, dtype: int64

# %%
df_cdr['date'].unique()
# Out:
# array(['2021-01-02 15:04:58', '2021-01-02 15:04:59',
#        '2021-01-02 15:05:00', ..., '2021-01-02 20:20:05',
#        '2021-01-02 20:20:00', '2021-01-02 20:24:00'], dtype=object)

# %%
df_cdr['date'].isnull().value_counts()
# Out:
# False    480548
# Name: date, dtype: int64

# %%
type(df_cdr['duration'][10])
# Out:
# numpy.int64

# %%
df_cdr['duration'].unique()
# Out:
# array([   0,   29,   33,   34,    5,    3,   16,   42,   30,  116,   28,
#          18,   35,   20,   26,    6,   31,    4,    8,   10,    7,   27,
#          14,   25,   22,   39,    1,   11,    2,    9,   21,   17,   23,
#          41,   13,   32,   24,   19,   15,   36,   50,   43,   57,  122,
#          12,  358,  141,   40,   72,  102,   49,   95,   62,  107,   48,
#          71,   91,   55,   78,   59,   65,   75,   51,   37,   56,   98,
#          81,  270,   73,   97,   70,   85,   38,  345,  120,  382,   83,
#          54,  197,   61,   80,  206,   64,  119,   99,   58,   86,  105,
#          44,   63,   52,   53,   68,  121,   67,  175,  301,  100,   45,
#          66,  232,   60,   84,   76,   92,  304,  115,   79,  182, 4055,
#          46,  329,   69,   74,  131,  400,  118,   89,  113,  133,   47,
#          82,  194,   90,   87,  103,  158,  149,  239,   93,   77,  110,
#         114,  112,  221,  111,   96,  299,  166,  129,  117,  125,  126,
# ...

# %%
df_cdr['duration'].value_counts()
# Out:
# 0      325749
# 3       52114
# 4       17134
# 5        8333
# 35       4784
#         ...
# 373         1
# 206         1
# 382         1
# 518         1
# 389         1
# Name: duration, Length: 278, dtype: int64

# %%
df_cdr['dst_number'].value_counts()
# Out:
# 9105721200    4
# 8069353220    4
# 6105321791    4
# 7604801227    3
# 7188495706    3
#              ..
# 5616993636    1
# 8282732260    1
# 7725621180    1
# 8056844042    1
# 4016352845    1
# Name: dst_number, Length: 479591, dtype: int64

# %%
df_cdr['dst_number'].unique()
# Out:
# array([9788367424, 6316652128, 9736973406, ..., 3609785233, 4017622411,
#        4016352845], dtype=int64)

# %%
type(df_cdr['dst_number'][0])
# Out:
# numpy.int64

# %%
df_cdr1 = pd.read_csv(r"Z:\AIDAILER\cdr\2021-06-30.csv",warn_bad_lines=True, error_bad_lines=False, engine="python")
# Out:
# C:\Users\trainee10\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\trainee10\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_cdr1.head()
# Out:
#                   date  src_number  dst_number  billed_number  duration  \
# 0  2021-06-30 14:39:29  8003741625  8003742683         800374        34
# 1  2021-06-30 14:42:20  8666009556  9786862257         978304        15
# 2  2021-06-30 14:46:15  9786861929  9786862257         978304        18
# 3  2021-06-30 14:47:01  9783126091  9783123318         617603         0
# 4  2021-06-30 14:47:07  2088528163  2088520895         208852        46
#
#    account_id         src_ip account_jurisdiction  account_billed_duration  \
# 0          38  148.72.171.85                Indet                       34
# 1          38  148.72.171.85                Indet                       15
# 2          38  148.72.171.85                Intra                       18
# 3          38  148.72.171.85                Intra                        0
# 4          38  148.72.171.85                Intra                       46
#
#    account_rate  account_cost  \
# 0      0.000000        0.0000
# ...

# %%
dfnew1 = df_cdr
