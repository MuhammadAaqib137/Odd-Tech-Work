# %%
import pandas as pd
df = pd.read_csv("Z:\AIDAILER\Tony DB 2021\lit-NE.csv",warn_bad_lines=True, error_bad_lines=False, engine="python")

# %%
df.head()
# Out:
#    Phone Cleaned  FullPhoneNumber personfirstname personmiddleinitial  \
# 0     6032680891       6032680891           SASHA                   M
# 1     6032680891       6032680891       KATHERINE                   A
# 2     9178226762       9178226762           DIANE                 NaN
# 3     5089639291       5089639291           SONYA                 NaN
# 4     6033830107       6033830107           DAVID                   E
#
#   personlastname     primaryaddress secondaryaddress     cityname state  \
# 0          HAMEL   1807 Hooksett Rd              NaN     Hooksett    NH
# 1          HAMEL   1807 Hooksett Rd              NaN     Hooksett    NH
# 2       GOULSTON      28 Caswell Dr              NaN    Greenland    NH
# 3        FONSECA       5 Tokanel Dr              NaN  Londonderry    NH
# 4        ROBERTS  400 Glen Ledge Rd              NaN         Glen    NH
#
#    ZipCode  ...  estimatedincomecode  CreditRating  NumberOfLinesOfCredit  \
# ...

# %%
type(df['FullPhoneNumber'][5])
# Out:
# numpy.int64

# %%
df['FullPhoneNumber'].value_counts()
# Out:
# 9786589634    25
# 6035246564    25
# 6037464619    20
# 6039240255    20
# 8143350415    20
#               ..
# 6039642079     1
# 6034325475     1
# 6039244204     1
# 6033303675     1
# 6034409938     1
# Name: FullPhoneNumber, Length: 261713, dtype: int64
