# %%
import pandas as pd

# %%
data = pd.read_csv('copy_finalized_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  state  cityname  persongender  personexactage  \
# 0           0     27       203             2              87
# 1           1     27      9381             1              83
# 2           2     27      1059             2               2
# 3           3     27      1059             1              62
# 4           4     27       135             2              50
#
#    personmaritalstatus  traveler  ZipCode  investment  estimatedincomecode  \
# 0                    3         0    86429           0                    4
# 1                    2         1    85939           1                   12
# 2                    3         0    85712           0                    9
# 3                    2         1    85736           1                   12
# 4                    3         0    85335           0                   16
#
#    timezone  PresenceOfCreditCard  CreditRating             Date  Duration  \
# ...

# %%
data["Date"][2000][9:]
# Out:
# '23:30'
