# %%
import pandas as pd

# %%
data = pd.read_csv('Transciptioned_data(Without_duplicate).csv')

# %%
data
# Out:
#                                            recoding_url    user  \
# 0     http://192.168.88.254/transcription_wav/transc...  m.aqib
# 1     http://192.168.88.254/transcription_wav/transc...  m.aqib
# 2     http://192.168.88.254/transcription_wav/transc...  m.aqib
# 3     http://192.168.88.254/transcription_wav/transc...  m.aqib
# 4     http://192.168.88.254/transcription_wav/transc...  m.aqib
# ...                                                 ...     ...
# 1726  http://192.168.88.254/transcription_wav/transc...  m.aqib
# 1727  http://192.168.88.254/transcription_wav/transc...  m.aqib
# 1728  http://192.168.88.254/transcription_wav/transc...  m.aqib
# 1729  http://192.168.88.254/transcription_wav/transc...  m.aqib
# 1730  http://192.168.88.254/transcription_wav/transc...  m.aqib
#
#                                        human_transcribe  \
# 0      about twenty thousand dollars about twenty th...
# 1                                       i am sorry i go
# ...

# %%
without_duplicate_list=list(data['human_transcribe'])

# %%
without_duplicate_list
# Out:
# [' about twenty thousand dollars about twenty thousand',
#  ' i am sorry i go',
#  ' I dont have any credit card debt roy',
#  ' may i help you ',
#  ' no thank you',
#  ' speak yeah ',
#  ' what do you want? ',
#  'no I don�t have no debt either',
#  'a debt free well you know what you can do without debt',
#  'a few',
#  'a fucker',
#  'a jame ten i give been waiting on your call but jane did you get my letter i jame gay in women de dan jane den do ye member talking to me jame a all right james oky i got to go then okay thanks for calling change',
#  'a month not a cross',
#  'a my credit card interest is a zeropercent',
#  'a three thousand dollars',
#  'a twelve thousand  none of these animal card  nine thousand on my visa card',
#  'aam i am in the lawyers office right now',
#  'about eight thousand dollars about eight thousand dollars',
#  'about forty about fourteen thousand',
#  'about ten dollars',
#  'about thirteen thousand',
#  'about thirty thousand',
# ...

# %%
junked_and_duplicated_data = pd.read_csv('transcribed_Data(with duplicate).csv')

# %%
duplicate_list=list(junked_and_duplicated_data['human_transcribe'])

# %%
len(duplicate_list)
# Out:
# 2320

# %%
len(new_data_list)
# Out:
# 4014230

# %%
len(duplicate_list)
# Out:
# 2320

# %%
len(without_duplicate_list)
# Out:
# 1731

# %%
data_clean = 
for i in duplicate_list:
    data_clean = data[data_clean['Bot Transcription'] != i]
# Out:
# []
