# %%
import pandas as pd
final_data1 = pd.read_csv('no_phone_num_full_cleaned_data.csv')
final_data1
# Out:
#        state       cityname persongender  personexactage personmaritalstatus  \
# 0         AZ  Bullhead City            M              87                   U
# 1         AZ         Taylor            F              83                   M
# 2         AZ         Tucson            M               2                   U
# 3         AZ         Tucson            F              62                   M
# 4         AZ      El Mirage            M              50                   U
# ...      ...            ...          ...             ...                 ...
# 335869    WI        Conover            F              69                   M
# 335870    WI    Fond Du Lac            F              84                   U
# 335871    WI         Neenah            M              88                   M
# 335872    WI      Green Bay            M              94                   M
# 335873    WI     Mc Farland            M              75                   M
#
# ...

# %%
final_data1.to_csv('Full_String_Data.csv')

# %%
copy_data = final_data1.copy()

# %%
count = 0
for i in final_data1['state'].unique():
    print(count, i)
    count+=1
# Out:
# 0 AZ
# 1 CA
# 2 CO
# 3 DC
# 4 FL
# 5 IA
# 6 IL
# 7 KY
# 8 LA
# 9 MA
# 10 MD
# 11 MI
# 12 MN
# 13 MO
# 14 MS
# 15 MT
# 16 ND
# 17 NE
# 18 NJ
# 19 NM
# 20 NV
# 21 NY
# 22 OK
# 23 OR
# 24 PA
# 25 RI
# 26 SC
# 27 SD
# 28 TX
# 29 VA
# 30 VT
# 31 WA
# 32 WI

# %%
import numpy as np
copy_data['state'].replace(to_replace = set(copy_data['state']), value = np.arange(0,33), inplace = True)

# %%
count = 0
for i in final_data1['personmaritalstatus'].unique():
    print(count, i)
    count+=1
# Out:
# 0 U
# 1 M
# 2 S
# 3 A
# 4 B

# %%
copy_data['personmaritalstatus'].replace(to_replace = set(copy_data['personmaritalstatus']), value = np.arange(0,5), inplace = True)

# %%
copy_data['personmaritalstatus'].unique()
# Out:
# array([1, 3, 2, 4, 0], dtype=int64)

# %%
count=0
for i in final_data1['cityname'].unique():
    print(count,i)
    count+=1
# Out:
# 0 Bullhead City
# 1 Taylor
# 2 Tucson
# 3 El Mirage
# 4 Glendale
# 5 Buckeye
# 6 Cave Creek
# 7 Mesa
# 8 Tracy
# 9 Tuolumne
# 10 Turlock
# 11 Waterford
# 12 Winton
# 13 Santa Rosa
# 14 Boonville
# 15 Clearlake
# 16 Clearlake Oks
# 17 Cloverdale
# 18 Cobb
# 19 Comptche
# 20 Covelo
# 21 Forestville
# 22 Windsor
# 23 Eureka
# 24 McKinleyville
# 25 Arcata
# 26 Bayside
# 27 Carlotta
# 28 Crescent City
# 29 Ferndale
# 30 Fortuna
# 31 Garberville
# 32 Redway
# 33 Rio Dell
# 34 Smith River
# 35 Redcrest
# 36 Amador City
# 37 Auburn
# 38 W Sacramento
# 39 Carmichael
# 40 Citrus Hts
# 41 Cool
# 42 Courtland
# 43 Davis
# 44 Dixon
# 45 El Dorado
# 46 Elk Grove
# 47 Elverta
# 48 Fair Oaks
# 49 Fiddletown
# 50 Folsom
# 51 Galt
# 52 Garden Valley
# 53 Georgetown
# 54 Santa Clara
# 55 Santa Cruz
# 56 Scotts Valley
# 57 Saratoga
# 58 Soquel
# 59 Watsonville
# 60 San Jose
# 61 Stockton
# 62 Acampo
# 63 Angels Camp
# 64 Richmond
# 65 San Pablo
# 66 San Rafael
# 67 Greenbrae
# 68 Bel Tiburon
# ...

# %%
copy_data['cityname'].replace(to_replace = set(copy_data['cityname']), value = np.arange(0,10329), inplace = True)

# %%
count=0
for i in final_data1['traveler'].unique():
    print(count,i)
    count+=1
# Out:
# 0 U
# 1 Y

# %%
copy_data['traveler'].replace(to_replace = set(copy_data['traveler']), value = np.arange(0,2), inplace = True)

# %%
count=0
for i in final_data1['estimatedincomecode'].unique():
    print(count,i)
    count+=1
# Out:
# 0 N
# 1 J
# 2 E
# 3 B
# 4 G
# 5 P
# 6 U
# 7 O
# 8 M
# 9 C
# 10 R
# 11 L
# 12 A
# 13 F
# 14 H
# 15 K
# 16 I
# 17 S
# 18 D
# 19 Q

# %%
copy_data['estimatedincomecode'].replace(to_replace = set(copy_data['estimatedincomecode']), value = np.arange(0,20), inplace = True)

# %%
count=0
for i in final_data1['timezone'].unique():
    print(count,i)
    count+=1
# Out:
# 0 M
# 1 P
# 2 U
# 3 E
# 4 C

# %%
copy_data['timezone'].replace(to_replace = set(copy_data['timezone']), value = np.arange(0,5), inplace = True)

# %%
count=0
for i in final_data1['PresenceOfCreditCard'].unique():
    print(count,i)
    count+=1
# Out:
# 0 U
# 1 Y

# %%
copy_data['PresenceOfCreditCard'].replace(to_replace = set(copy_data['PresenceOfCreditCard']), value = np.arange(0,2), inplace = True)

# %%
copy_data['state']
# Out:
# 0         18
# 1         18
# 2         18
# 3         18
# 4         18
#           ..
# 335869    16
# 335870    16
# 335871    16
# 335872    16
# 335873    16
# Name: state, Length: 335874, dtype: int64

# %%
copy_data
# Out:
#         state  cityname persongender  personexactage  personmaritalstatus  \
# 0          18      5768            M              87                    1
# 1          18      4600            F              83                    3
# 2          18      4373            M               2                    1
# 3          18      4373            F              62                    3
# 4          18      3375            M              50                    1
# ...       ...       ...          ...             ...                  ...
# 335869     16       651            F              69                    3
# 335870     16      1520            F              84                    1
# 335871     16      3163            M              88                    3
# 335872     16      9064            M              94                    3
# 335873     16      5988            M              75                    3
#
#         traveler  ZipCode investment  estimatedincomecode  timezone  \
# ...

# %%
#persongender
#creditRating
#investment
count=0
for i in final_data1['persongender'].unique():
    print(count,i)
    count+=1
# Out:
# 0 M
# 1 F
# 2 U

# %%
copy_data['persongender'].replace(to_replace = set(copy_data['persongender']), value = np.arange(0,3), inplace = True)

# %%
count=0
for i in final_data1['CreditRating'].unique():
    print(count,i)
    count+=1
# Out:
# 0 B
# 1 C
# 2 E
# 3 D
# 4 U
# 5 A
# 6 F
# 7 G
# 8 H

# %%
copy_data['CreditRating'].replace(to_replace = set(copy_data['CreditRating']), value = np.arange(0,9), inplace = True)

# %%
count=0
for i in final_data1['investment'].unique():
    print(count,i)
    count+=1
# Out:
# 0 U
# 1 Y

# %%
copy_data['investment'].replace(to_replace = set(copy_data['investment']), value = np.arange(0,2), inplace = True)

# %%
copy_data
# Out:
#         state  cityname  persongender  personexactage  personmaritalstatus  \
# 0          18      5768             0              87                    1
# 1          18      4600             1              83                    3
# 2          18      4373             0               2                    1
# 3          18      4373             1              62                    3
# 4          18      3375             0              50                    1
# ...       ...       ...           ...             ...                  ...
# 335869     16       651             1              69                    3
# 335870     16      1520             1              84                    1
# 335871     16      3163             0              88                    3
# 335872     16      9064             0              94                    3
# 335873     16      5988             0              75                    3
#
# ...

# %%
# copy_data.to_csv('copy_finalized_data.csv')

# %%
copy_data
# Out:
#         state  cityname  persongender  personexactage  personmaritalstatus  \
# 0          18      5768             0              87                    1
# 1          18      4600             1              83                    3
# 2          18      4373             0               2                    1
# 3          18      4373             1              62                    3
# 4          18      3375             0              50                    1
# ...       ...       ...           ...             ...                  ...
# 335869     16       651             1              69                    3
# 335870     16      1520             1              84                    1
# 335871     16      3163             0              88                    3
# 335872     16      9064             0              94                    3
# 335873     16      5988             0              75                    3
#
# ...

# %%
# finalized_data = pd.read_csv('copy_finalized_data.csv')
# finalized_data

# %%
# finalized_data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
# finalized_data

# %%
time_ = [ copy_data['Date'][i][9:] for i in range(len(copy_data['Date'])) ]

time_
# Out:
# ['19:34',
#  '17:22',
#  '22:34',
#  ' 17:09',
#  ' 20:28',
#  ' 18:39',
#  '18:31',
#  ' 21:17',
#  '23:11',
#  '18:31',
#  '18:24',
#  '19:36',
#  '21:18',
#  ' 16:07',
#  ' 17:52',
#  '21:31',
#  ' 17:27',
#  ' 20:49',
#  ' 18:43',
#  ' 18:33',
#  '17:40',
#  '18:45',
#  ' 16:10',
#  ' 21:57',
#  ' 16:07',
#  ' 17:12',
#  ' 17:15',
#  ' 16:00',
#  ' 19:14',
#  ' 18:06',
#  ' 16:29',
#  ' 17:45',
#  ' 18:06',
#  ' 16:09',
#  ' 17:20',
#  ' 20:39',
#  ' 17:54',
#  ' 20:11',
#  ' 18:03',
#  ' 18:04',
#  ' 20:33',
#  ' 16:00',
#  ' 20:16',
#  ' 21:12',
#  ' 18:00',
#  ' 16:25',
#  ' 16:34',
#  ' 21:40',
#  ' 20:35',
#  '22:41',
#  ' 16:08',
#  ' 19:25',
#  '17:41',
#  ' 18:09',
#  ' 20:19',
#  ' 16:26',
#  ' 17:56',
#  ' 16:26',
#  ' 17:52',
#  ' 18:13',
#  ' 16:23',
#  ' 16:01',
#  ' 18:15',
#  ' 18:25',
#  ' 17:02',
#  '20:33',
#  ' 19:28',
#  ' 16:10',
#  ' 16:29',
#  ' 16:48',
#  '20:44',
#  ' 18:16',
#  ' 17:50',
#  '22:28',
#  ' 18:19',
#  ' 16:07',
#  ' 16:24',
#  ' 16:22',
# ...

# %%
time = []
for i in time_:
    time.append(i.strip())

# %%
copy_data['Date'] = time

# %%
copy_data.rename(columns={'Date':'Time'},inplace = True)

# %%
copy_data['state']=final_data1['state']

# %%
copy_data['state']
# Out:
# 0         AZ
# 1         AZ
# 2         AZ
# 3         AZ
# 4         AZ
#           ..
# 335869    WI
# 335870    WI
# 335871    WI
# 335872    WI
# 335873    WI
# Name: state, Length: 335874, dtype: object

# %%
copy_data.rename(columns={'Date':'Time'},inplace = True)

# %%
copy_data['Time']=time

# %%
copy_data['Time']
# Out:
# 0         19:34
# 1         17:22
# 2         22:34
# 3         17:09
# 4         20:28
#           ...
# 335869    18:34
# 335870    15:36
# 335871    20:18
# 335872    18:29
# 335873    18:15
# Name: Time, Length: 335874, dtype: object

# %%
# finalized_data.to_csv('finalized_data.csv')

# %%
# finalized_data = pd.read_csv('finalized_data.csv')

# %%
# finalized_data.drop('Unnamed: 0',axis=1,inplace=True)
# finalized_data

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov 19 11:44:02 2021

@author: ashba
"""

import us
import pytz
from datetime import datetime


def getlocaltime(time_zones,dt ):
    try: 
        dt = datetime.strptime(dt, '%H:%M')
        return pytz.timezone(time_zones).fromutc(dt)
    except:
        print (dt)
        
        
        
copy_data['time_zones'] = copy_data.apply(lambda row:us.states.lookup(row.state).time_zones[0], axis=1)
copy_data['localtime'] = copy_data.apply(  lambda row: getlocaltime(row.time_zones, row.Time) , axis=1)

# %%
copy_data
# Out:
#        state  cityname  persongender  personexactage  personmaritalstatus  \
# 0         AZ      5768             0              87                    1
# 1         AZ      4600             1              83                    3
# 2         AZ      4373             0               2                    1
# 3         AZ      4373             1              62                    3
# 4         AZ      3375             0              50                    1
# ...      ...       ...           ...             ...                  ...
# 335869    WI       651             1              69                    3
# 335870    WI      1520             1              84                    1
# 335871    WI      3163             0              88                    3
# 335872    WI      9064             0              94                    3
# 335873    WI      5988             0              75                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  timezone  \
# ...

# %%
localtime = copy_data['localtime'].to_list()
hr = [str(t).split(":")[0].split()[-1] for t in localtime]

# %%
copy_data['hour'] = hr
copy_data.head()
# Out:
#   state  cityname  persongender  personexactage  personmaritalstatus  \
# 0    AZ      5768             0              87                    1
# 1    AZ      4600             1              83                    3
# 2    AZ      4373             0               2                    1
# 3    AZ      4373             1              62                    3
# 4    AZ      3375             0              50                    1
#
#    traveler  ZipCode  investment  estimatedincomecode  timezone  \
# 0         0    86429           0                    6         3
# 1         1    85939           1                    3         3
# 2         0    85712           0                   13         3
# 3         1    85736           1                    3         3
# 4         0    85335           0                   12         3
#
#    PresenceOfCreditCard  CreditRating   Time  Duration  Label  \
# 0                     0             1  19:34         0      0
# ...

# %%
# !pip install us

# %%
copy_data.drop(['time_zones','localtime'],axis=1,inplace=True)

# %%
copy_data=copy_data[['state','cityname','persongender','personexactage','personmaritalstatus','traveler','ZipCode','investment','estimatedincomecode','timezone','PresenceOfCreditCard','CreditRating','Time','Duration','hour','Label']]

# %%
copy_data
# Out:
#        state  cityname  persongender  personexactage  personmaritalstatus  \
# 0         AZ      5768             0              87                    1
# 1         AZ      4600             1              83                    3
# 2         AZ      4373             0               2                    1
# 3         AZ      4373             1              62                    3
# 4         AZ      3375             0              50                    1
# ...      ...       ...           ...             ...                  ...
# 335869    WI       651             1              69                    3
# 335870    WI      1520             1              84                    1
# 335871    WI      3163             0              88                    3
# 335872    WI      9064             0              94                    3
# 335873    WI      5988             0              75                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  timezone  \
# ...

# %%
full_final_data = copy_data.copy()

# %%
full_final_data
# Out:
#        state  cityname  persongender  personexactage  personmaritalstatus  \
# 0         AZ      5768             0              87                    1
# 1         AZ      4600             1              83                    3
# 2         AZ      4373             0               2                    1
# 3         AZ      4373             1              62                    3
# 4         AZ      3375             0              50                    1
# ...      ...       ...           ...             ...                  ...
# 335869    WI       651             1              69                    3
# 335870    WI      1520             1              84                    1
# 335871    WI      3163             0              88                    3
# 335872    WI      9064             0              94                    3
# 335873    WI      5988             0              75                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  timezone  \
# ...

# %%
full_final_data.drop(['timezone','Time'],axis=1,inplace=True)
full_final_data
# Out:
#        state  cityname  persongender  personexactage  personmaritalstatus  \
# 0         AZ      5768             0              87                    1
# 1         AZ      4600             1              83                    3
# 2         AZ      4373             0               2                    1
# 3         AZ      4373             1              62                    3
# 4         AZ      3375             0              50                    1
# ...      ...       ...           ...             ...                  ...
# 335869    WI       651             1              69                    3
# 335870    WI      1520             1              84                    1
# 335871    WI      3163             0              88                    3
# 335872    WI      9064             0              94                    3
# 335873    WI      5988             0              75                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  \
# ...

# %%
# changing states into numeric
full_final_data['state'].replace(to_replace = set(full_final_data['state']), value = np.arange(0,33), inplace = True)

# %%
full_final_data
# Out:
#         state  cityname  persongender  personexactage  personmaritalstatus  \
# 0          18      5768             0              87                    1
# 1          18      4600             1              83                    3
# 2          18      4373             0               2                    1
# 3          18      4373             1              62                    3
# 4          18      3375             0              50                    1
# ...       ...       ...           ...             ...                  ...
# 335869     16       651             1              69                    3
# 335870     16      1520             1              84                    1
# 335871     16      3163             0              88                    3
# 335872     16      9064             0              94                    3
# 335873     16      5988             0              75                    3
#
#         traveler  ZipCode  investment  estimatedincomecode  \
# ...

# %%
full_final_data.to_csv('Full_Finalized_numeric_data_for_training.csv')
