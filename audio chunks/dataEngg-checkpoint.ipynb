# %%
import pandas as pd

# %%
df = pd.read_csv(r"Z:\AIDAILER\Tony DB 2021\lit-AK.csv")
df
# Out:
#         Phone Cleaned  FullPhoneNumber personfirstname personmiddleinitial  \
# 0          9072272643       9072272643         LEONARD                   L
# 1          9073609503       9073609503         CHARLES                   P
# 2          9072742175       9072742175           JAMES                   R
# 3          9072743803       9072743803            DEAN                 NaN
# 4          9072768688       9072768688           KAREN                   S
# ...               ...              ...             ...                 ...
# 110745     9072529404       9072529404        PATRICIA                   A
# 110746     9072327715       9072327715          TRAVIS                 NaN
# 110747     9073500854       9073500854          ALEXYS                   X
# 110748     9073500854       9073500854          SHEILA                   A
# 110749     9073500997       9073500997            KYLE                   M
#
#        personlastname      primaryaddress secondaryaddress   cityname state  \
# 0               BOOTH          PO Box 114              NaN       Hope    AK
# 1               FLYNN      1519 Hidden Ln              NaN  Anchorage    AK
# 2            LIEBSACK     1358 W 11th Ave              NaN  Anchorage    AK
# 3               FOUTS      446 E 10th Ave              NaN  Anchorage    AK
# 4               SNEAD            510 L St          Apt 905  Anchorage    AK
# ...               ...                 ...              ...        ...   ...
# 110745          LYTLE           PO Box 64              NaN   Soldotna    AK
# 110746         ASHING       400 S Rose Dr              NaN     Palmer    AK
# 110747           LANG  8717 Brookridge Dr              NaN  Anchorage    AK
# 110748           LANG  8717 Brookridge Dr              NaN  Anchorage    AK
# 110749            ORR    3831 Gunwale Cir              NaN  Anchorage    AK
#
#         ZipCode  ...  estimatedincomecode  CreditRating  \
# 0         99605  ...                    M             B
# 1         99501  ...                    S             A
# 2         99501  ...                    R             B
# 3         99501  ...                    H             D
# 4         99501  ...                    R             B
# ...         ...  ...                  ...           ...
# 110745    99669  ...                    N             C
# 110746    99645  ...                    M             C
# 110747    99504  ...                    S             D
# 110748    99504  ...                    S             D
# 110749    99516  ...                    S             C
#
#         NumberOfLinesOfCredit  Credit_RangeOfNewCredit  \
# 0                           U                        U
# 1                           U                        U
# 2                           U                        U
# 3                           U                        U
# 4                           2                        5
# ...                       ...                      ...
# 110745                      U                        U
# 110746                      2                        U
# 110747                      1                        7
# 110748                      1                        7
# 110749                      U                        U
#
#        homeownerprobabilitymodel Disconnected National DNC Internal DNC  \
# 0                              H            N            N            N
# 1                              H            N            Y            N
# 2                              H            N            N            N
# 3                              H            N            N            N
# 4                              H            N            N            N
# ...                          ...          ...          ...          ...
# 110745                         H            N            N            N
# 110746                         H            N            Y            N
# 110747                         H            N            Y            N
# 110748                         H            N            Y            N
# 110749                         H            N            Y            N
#
#        Cellphone Litigator
# 0              Y         N
# 1              Y         N
# 2              N         N
# 3              N         N
# 4              N         N
# ...          ...       ...
# 110745         Y         N
# 110746         Y         N
# 110747         Y         N
# 110748         Y         N
# 110749         Y         N
#
# [110750 rows x 25 columns]

# %%
df['ZipCode']
# Out:
# 0         99605
# 1         99501
# 2         99501
# 3         99501
# 4         99501
#           ...
# 110745    99669
# 110746    99645
# 110747    99504
# 110748    99504
# 110749    99516
# Name: ZipCode, Length: 110750, dtype: int64

# %%
df.describe()
# Out:
#        Phone Cleaned  FullPhoneNumber        ZipCode  persondateofbirthmonth  \
# count   1.107500e+05     1.107500e+05  110750.000000           110750.000000
# mean    8.852382e+09     8.852382e+09   99608.125670                5.325418
# std     1.033365e+09     1.033365e+09     112.283172                3.991757
# min     2.012136e+09     2.012136e+09   99501.000000                0.000000
# 25%     9.072774e+09     9.072774e+09   99508.000000                1.000000
# 50%     9.073736e+09     9.073736e+09   99577.000000                5.000000
# 75%     9.076885e+09     9.076885e+09   99701.000000                9.000000
# max     9.899801e+09     9.899801e+09   99929.000000               12.000000
#
#        persondateofbirthday  persondateofbirthyear  personexactage
# count         110750.000000          110750.000000   110750.000000
# mean               6.199955            1878.998068       55.521463
# std                9.387807             395.315136       19.679969
# min                0.000000               0.000000        0.000000
# 25%                0.000000            1949.000000       44.000000
# 50%                0.000000            1960.000000       59.000000
# 75%               12.000000            1972.000000       69.000000
# max               31.000000            1999.000000      102.000000

# %%
df['FullPhoneNumber'].unique()
# Out:
# array([9072272643, 9073609503, 9072742175, ..., 9072327715, 9073500854,
#        9073500997], dtype=int64)

# %%
len(df['FullPhoneNumber'])
# Out:
# 110750

# %%
df.shape
# Out:
# (110750, 25)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Phone Cleaned  FullPhoneNumber personfirstname personmiddleinitial  \
# 0          9072272643       9072272643         LEONARD                   L
# 1          9073609503       9073609503         CHARLES                   P
# 2          9072742175       9072742175           JAMES                   R
# 3          9072743803       9072743803            DEAN                 NaN
# 4          9072768688       9072768688           KAREN                   S
# ...               ...              ...             ...                 ...
# 110745     9072529404       9072529404        PATRICIA                   A
# 110746     9072327715       9072327715          TRAVIS                 NaN
# 110747     9073500854       9073500854          ALEXYS                   X
# 110748     9073500854       9073500854          SHEILA                   A
# 110749     9073500997       9073500997            KYLE                   M
#
#        personlastname      primaryaddress secondaryaddress   cityname state  \
# 0               BOOTH          PO Box 114              NaN       Hope    AK
# 1               FLYNN      1519 Hidden Ln              NaN  Anchorage    AK
# 2            LIEBSACK     1358 W 11th Ave              NaN  Anchorage    AK
# 3               FOUTS      446 E 10th Ave              NaN  Anchorage    AK
# 4               SNEAD            510 L St          Apt 905  Anchorage    AK
# ...               ...                 ...              ...        ...   ...
# 110745          LYTLE           PO Box 64              NaN   Soldotna    AK
# 110746         ASHING       400 S Rose Dr              NaN     Palmer    AK
# 110747           LANG  8717 Brookridge Dr              NaN  Anchorage    AK
# 110748           LANG  8717 Brookridge Dr              NaN  Anchorage    AK
# 110749            ORR    3831 Gunwale Cir              NaN  Anchorage    AK
#
#         ZipCode  ...  estimatedincomecode  CreditRating  \
# 0         99605  ...                    M             B
# 1         99501  ...                    S             A
# 2         99501  ...                    R             B
# 3         99501  ...                    H             D
# 4         99501  ...                    R             B
# ...         ...  ...                  ...           ...
# 110745    99669  ...                    N             C
# 110746    99645  ...                    M             C
# 110747    99504  ...                    S             D
# 110748    99504  ...                    S             D
# 110749    99516  ...                    S             C
#
#         NumberOfLinesOfCredit  Credit_RangeOfNewCredit  \
# 0                           U                        U
# 1                           U                        U
# 2                           U                        U
# 3                           U                        U
# 4                           2                        5
# ...                       ...                      ...
# 110745                      U                        U
# 110746                      2                        U
# 110747                      1                        7
# 110748                      1                        7
# 110749                      U                        U
#
#        homeownerprobabilitymodel Disconnected National DNC Internal DNC  \
# 0                              H            N            N            N
# 1                              H            N            Y            N
# 2                              H            N            N            N
# 3                              H            N            N            N
# 4                              H            N            N            N
# ...                          ...          ...          ...          ...
# 110745                         H            N            N            N
# 110746                         H            N            Y            N
# 110747                         H            N            Y            N
# 110748                         H            N            Y            N
# 110749                         H            N            Y            N
#
#        Cellphone Litigator
# 0              Y         N
# 1              Y         N
# 2              N         N
# 3              N         N
# 4              N         N
# ...          ...       ...
# 110745         Y         N
# 110746         Y         N
# 110747         Y         N
# 110748         Y         N
# 110749         Y         N
#
# [110750 rows x 25 columns]>

# %%
df.describe()
# Out:
#        Phone Cleaned  FullPhoneNumber        ZipCode  persondateofbirthmonth  \
# count   1.107500e+05     1.107500e+05  110750.000000           110750.000000
# mean    8.852382e+09     8.852382e+09   99608.125670                5.325418
# std     1.033365e+09     1.033365e+09     112.283172                3.991757
# min     2.012136e+09     2.012136e+09   99501.000000                0.000000
# 25%     9.072774e+09     9.072774e+09   99508.000000                1.000000
# 50%     9.073736e+09     9.073736e+09   99577.000000                5.000000
# 75%     9.076885e+09     9.076885e+09   99701.000000                9.000000
# max     9.899801e+09     9.899801e+09   99929.000000               12.000000
#
#        persondateofbirthday  persondateofbirthyear  personexactage
# count         110750.000000          110750.000000   110750.000000
# mean               6.199955            1878.998068       55.521463
# std                9.387807             395.315136       19.679969
# min                0.000000               0.000000        0.000000
# 25%                0.000000            1949.000000       44.000000
# 50%                0.000000            1960.000000       59.000000
# 75%               12.000000            1972.000000       69.000000
# max               31.000000            1999.000000      102.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110750 entries, 0 to 110749
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Phone Cleaned              110750 non-null  int64
#  1   FullPhoneNumber            110750 non-null  int64
#  2   personfirstname            110750 non-null  object
#  3   personmiddleinitial        95361 non-null   object
#  4   personlastname             110747 non-null  object
#  5   primaryaddress             110750 non-null  object
#  6   secondaryaddress           11115 non-null   object
#  7   cityname                   110750 non-null  object
#  8   state                      110750 non-null  object
#  9   ZipCode                    110750 non-null  int64
#  10  persondateofbirthmonth     110750 non-null  int64
#  11  persondateofbirthday       110750 non-null  int64
#  12  persondateofbirthyear      110750 non-null  int64
#  13  personexactage             110750 non-null  int64
#  14  IsMobile                   110750 non-null  object
#  15  estimatedincomecode        110750 non-null  object
#  16  CreditRating               110750 non-null  object
#  17  NumberOfLinesOfCredit      110750 non-null  object
#  18  Credit_RangeOfNewCredit    110750 non-null  object
#  19  homeownerprobabilitymodel  110750 non-null  object
#  20  Disconnected               110750 non-null  object
#  21  National DNC               110750 non-null  object
#  22  Internal DNC               110750 non-null  object
#  23  Cellphone                  110750 non-null  object
#  24  Litigator                  110750 non-null  object
# dtypes: int64(7), object(18)
# memory usage: 21.1+ MB

# %%
df.isnull().any()
# Out:
# Phone Cleaned                False
# FullPhoneNumber              False
# personfirstname              False
# personmiddleinitial           True
# personlastname                True
# primaryaddress               False
# secondaryaddress              True
# cityname                     False
# state                        False
# ZipCode                      False
# persondateofbirthmonth       False
# persondateofbirthday         False
# persondateofbirthyear        False
# personexactage               False
# IsMobile                     False
# estimatedincomecode          False
# CreditRating                 False
# NumberOfLinesOfCredit        False
# Credit_RangeOfNewCredit      False
# homeownerprobabilitymodel    False
# Disconnected                 False
# National DNC                 False
# Internal DNC                 False
# Cellphone                    False
# Litigator                    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Phone Cleaned                    0
# FullPhoneNumber                  0
# personfirstname                  0
# personmiddleinitial          15389
# personlastname                   3
# primaryaddress                   0
# secondaryaddress             99635
# cityname                         0
# state                            0
# ZipCode                          0
# persondateofbirthmonth           0
# persondateofbirthday             0
# persondateofbirthyear            0
# personexactage                   0
# IsMobile                         0
# estimatedincomecode              0
# CreditRating                     0
# NumberOfLinesOfCredit            0
# Credit_RangeOfNewCredit          0
# homeownerprobabilitymodel        0
# Disconnected                     0
# National DNC                     0
# Internal DNC                     0
# Cellphone                        0
# Litigator                        0
# dtype: int64

# %%
data = pd.DataFrame(df)

# %%
data
# Out:
#         Phone Cleaned  FullPhoneNumber personfirstname personmiddleinitial  \
# 0          9072272643       9072272643         LEONARD                   L
# 1          9073609503       9073609503         CHARLES                   P
# 2          9072742175       9072742175           JAMES                   R
# 3          9072743803       9072743803            DEAN                 NaN
# 4          9072768688       9072768688           KAREN                   S
# ...               ...              ...             ...                 ...
# 110745     9072529404       9072529404        PATRICIA                   A
# 110746     9072327715       9072327715          TRAVIS                 NaN
# 110747     9073500854       9073500854          ALEXYS                   X
# 110748     9073500854       9073500854          SHEILA                   A
# 110749     9073500997       9073500997            KYLE                   M
#
#        personlastname      primaryaddress secondaryaddress   cityname state  \
# 0               BOOTH          PO Box 114              NaN       Hope    AK
# 1               FLYNN      1519 Hidden Ln              NaN  Anchorage    AK
# 2            LIEBSACK     1358 W 11th Ave              NaN  Anchorage    AK
# 3               FOUTS      446 E 10th Ave              NaN  Anchorage    AK
# 4               SNEAD            510 L St          Apt 905  Anchorage    AK
# ...               ...                 ...              ...        ...   ...
# 110745          LYTLE           PO Box 64              NaN   Soldotna    AK
# 110746         ASHING       400 S Rose Dr              NaN     Palmer    AK
# 110747           LANG  8717 Brookridge Dr              NaN  Anchorage    AK
# 110748           LANG  8717 Brookridge Dr              NaN  Anchorage    AK
# 110749            ORR    3831 Gunwale Cir              NaN  Anchorage    AK
#
#         ZipCode  ...  estimatedincomecode  CreditRating  \
# 0         99605  ...                    M             B
# 1         99501  ...                    S             A
# 2         99501  ...                    R             B
# 3         99501  ...                    H             D
# 4         99501  ...                    R             B
# ...         ...  ...                  ...           ...
# 110745    99669  ...                    N             C
# 110746    99645  ...                    M             C
# 110747    99504  ...                    S             D
# 110748    99504  ...                    S             D
# 110749    99516  ...                    S             C
#
#         NumberOfLinesOfCredit  Credit_RangeOfNewCredit  \
# 0                           U                        U
# 1                           U                        U
# 2                           U                        U
# 3                           U                        U
# 4                           2                        5
# ...                       ...                      ...
# 110745                      U                        U
# 110746                      2                        U
# 110747                      1                        7
# 110748                      1                        7
# 110749                      U                        U
#
#        homeownerprobabilitymodel Disconnected National DNC Internal DNC  \
# 0                              H            N            N            N
# 1                              H            N            Y            N
# 2                              H            N            N            N
# 3                              H            N            N            N
# 4                              H            N            N            N
# ...                          ...          ...          ...          ...
# 110745                         H            N            N            N
# 110746                         H            N            Y            N
# 110747                         H            N            Y            N
# 110748                         H            N            Y            N
# 110749                         H            N            Y            N
#
#        Cellphone Litigator
# 0              Y         N
# 1              Y         N
# 2              N         N
# 3              N         N
# 4              N         N
# ...          ...       ...
# 110745         Y         N
# 110746         Y         N
# 110747         Y         N
# 110748         Y         N
# 110749         Y         N
#
# [110750 rows x 25 columns]

# %%
data = data.drop(['personlastname', 'personfirstname', 'primaryaddress','secondaryaddress','personmiddleinitial', 'cityname', 'ZipCode', 'persondateofbirthmonth','persondateofbirthday',  'persondateofbirthyear', 'Litigator'], axis=1)

# %%
data = data.drop(['Phone Cleaned'], axis=1)

# %%
data
# Out:
#         FullPhoneNumber state  personexactage IsMobile estimatedincomecode  \
# 0            9072272643    AK              79        T                   M
# 1            9073609503    AK              77        T                   S
# 2            9072742175    AK              61        F                   R
# 3            9072743803    AK              80        F                   H
# 4            9072768688    AK              75        F                   R
# ...                 ...   ...             ...      ...                 ...
# 110745       9072529404    AK              61        T                   N
# 110746       9072327715    AK               0        T                   M
# 110747       9073500854    AK              48        T                   S
# 110748       9073500854    AK              44        T                   S
# 110749       9073500997    AK              50        T                   S
#
#        CreditRating NumberOfLinesOfCredit Credit_RangeOfNewCredit  \
# 0                 B                     U                       U
# 1                 A                     U                       U
# 2                 B                     U                       U
# 3                 D                     U                       U
# 4                 B                     2                       5
# ...             ...                   ...                     ...
# 110745            C                     U                       U
# 110746            C                     2                       U
# 110747            D                     1                       7
# 110748            D                     1                       7
# 110749            C                     U                       U
#
#        homeownerprobabilitymodel Disconnected National DNC Internal DNC  \
# 0                              H            N            N            N
# 1                              H            N            Y            N
# 2                              H            N            N            N
# 3                              H            N            N            N
# 4                              H            N            N            N
# ...                          ...          ...          ...          ...
# 110745                         H            N            N            N
# 110746                         H            N            Y            N
# 110747                         H            N            Y            N
# 110748                         H            N            Y            N
# 110749                         H            N            Y            N
#
#        Cellphone
# 0              Y
# 1              Y
# 2              N
# 3              N
# 4              N
# ...          ...
# 110745         Y
# 110746         Y
# 110747         Y
# 110748         Y
# 110749         Y
#
# [110750 rows x 13 columns]

# %%
data.isnull().any()
# Out:
# FullPhoneNumber              False
# state                        False
# personexactage               False
# IsMobile                     False
# estimatedincomecode          False
# CreditRating                 False
# NumberOfLinesOfCredit        False
# Credit_RangeOfNewCredit      False
# homeownerprobabilitymodel    False
# Disconnected                 False
# National DNC                 False
# Internal DNC                 False
# Cellphone                    False
# dtype: bool

# %%
data['FullPhoneNumber'].isnull().values.any()
# Out:
# False

# %%
data['personexactage']
# Out:
# 0         79
# 1         77
# 2         61
# 3         80
# 4         75
#           ..
# 110745    61
# 110746     0
# 110747    48
# 110748    44
# 110749    50
# Name: personexactage, Length: 110750, dtype: int64

# %%
data.head(10)
# Out:
#    FullPhoneNumber state  personexactage IsMobile estimatedincomecode  \
# 0       9072272643    AK              79        T                   M
# 1       9073609503    AK              77        T                   S
# 2       9072742175    AK              61        F                   R
# 3       9072743803    AK              80        F                   H
# 4       9072768688    AK              75        F                   R
# 5       9079526719    AK              47        T                   O
# 6       9072585104    AK             101        F                   N
# 7       9072585104    AK             101        F                   N
# 8       9073981394    AK              53        T                   M
# 9       9072771257    AK              62        F                   S
#
#   CreditRating NumberOfLinesOfCredit Credit_RangeOfNewCredit  \
# 0            B                     U                       U
# 1            A                     U                       U
# 2            B                     U                       U
# 3            D                     U                       U
# 4            B                     2                       5
# 5            C                     2                       7
# 6            B                     7                       U
# 7            B                     7                       U
# 8            F                     3                       U
# 9            D                     1                       4
#
#   homeownerprobabilitymodel Disconnected National DNC Internal DNC Cellphone
# 0                         H            N            N            N         Y
# 1                         H            N            Y            N         Y
# 2                         H            N            N            N         N
# 3                         H            N            N            N         N
# 4                         H            N            N            N         N
# 5                         H            N            Y            N         Y
# 6                         H            N            Y            N         N
# 7                         H            N            Y            N         N
# 8                         H            N            Y            N         Y
# 9                         H            N            N            N         N

# %%
data.iloc[110746]
# Out:
# FullPhoneNumber              9072327715
# state                                AK
# personexactage                        0
# IsMobile                              T
# estimatedincomecode                   M
# CreditRating                          C
# NumberOfLinesOfCredit                 2
# Credit_RangeOfNewCredit               U
# homeownerprobabilitymodel             H
# Disconnected                          N
# National DNC                          Y
# Internal DNC                          N
# Cellphone                             Y
# Name: 110746, dtype: object

# %%
data.isnull().values.any()
# Out:
# False

# %%
data = data[data['personexactage'] <= 0]

# %%
data1 = data
data1
# Out:
#         FullPhoneNumber state  personexactage IsMobile estimatedincomecode  \
# 10           9072771257    AK               0        F                   Q
# 88           9072432220    AK               0        F                   J
# 92           9072584757    AK               0        F                   S
# 136          9072434596    AK               0        F                   N
# 175          9073364672    AK               0        F                   O
# ...                 ...   ...             ...      ...                 ...
# 110602       9073988452    AK               0        T                   O
# 110678       9077478649    AK               0        F                   C
# 110733       9072226908    AK               0        F                   O
# 110735       9075909766    AK               0        T                   N
# 110746       9072327715    AK               0        T                   M
#
#        CreditRating NumberOfLinesOfCredit Credit_RangeOfNewCredit  \
# 10                D                     1                       4
# 88                D                     3                       U
# 92                B                     2                       U
# 136               D                     U                       U
# 175               C                     1                       7
# ...             ...                   ...                     ...
# 110602            B                     1                       7
# 110678            C                     U                       U
# 110733            C                     1                       7
# 110735            A                     U                       U
# 110746            C                     2                       U
#
#        homeownerprobabilitymodel Disconnected National DNC Internal DNC  \
# 10                             H            N            N            N
# 88                             H            N            N            N
# 92                             H            N            Y            N
# 136                            H            N            Y            N
# 175                            H            N            Y            N
# ...                          ...          ...          ...          ...
# 110602                         H            N            Y            N
# 110678                         H            N            Y            N
# 110733                         H            N            N            N
# 110735                         U            N            N            N
# 110746                         H            N            Y            N
#
#        Cellphone
# 10             N
# 88             N
# 92             N
# 136            N
# 175            N
# ...          ...
# 110602         Y
# 110678         N
# 110733         N
# 110735         Y
# 110746         Y
#
# [4675 rows x 13 columns]

# %%
data1 = data[data['personexactage'] > 0]
data1
# Out:
# Empty DataFrame
# Columns: [FullPhoneNumber, state, personexactage, IsMobile, estimatedincomecode, CreditRating, NumberOfLinesOfCredit, Credit_RangeOfNewCredit, homeownerprobabilitymodel, Disconnected, National DNC, Internal DNC, Cellphone]
# Index: []

# %%
data1.isnull().values.any()
# Out:
# False

# %%
df_mean = data['personexactage'].mean()

# %%
df_mean
# Out:
# 0.0

# %%
data
# Out:
#         FullPhoneNumber state  personexactage IsMobile estimatedincomecode  \
# 10           9072771257    AK               0        F                   Q
# 88           9072432220    AK               0        F                   J
# 92           9072584757    AK               0        F                   S
# 136          9072434596    AK               0        F                   N
# 175          9073364672    AK               0        F                   O
# ...                 ...   ...             ...      ...                 ...
# 110602       9073988452    AK               0        T                   O
# 110678       9077478649    AK               0        F                   C
# 110733       9072226908    AK               0        F                   O
# 110735       9075909766    AK               0        T                   N
# 110746       9072327715    AK               0        T                   M
#
#        CreditRating NumberOfLinesOfCredit Credit_RangeOfNewCredit  \
# 10                D                     1                       4
# 88                D                     3                       U
# 92                B                     2                       U
# 136               D                     U                       U
# 175               C                     1                       7
# ...             ...                   ...                     ...
# 110602            B                     1                       7
# 110678            C                     U                       U
# 110733            C                     1                       7
# 110735            A                     U                       U
# 110746            C                     2                       U
#
#        homeownerprobabilitymodel Disconnected National DNC Internal DNC  \
# 10                             H            N            N            N
# 88                             H            N            N            N
# 92                             H            N            Y            N
# 136                            H            N            Y            N
# 175                            H            N            Y            N
# ...                          ...          ...          ...          ...
# 110602                         H            N            Y            N
# 110678                         H            N            Y            N
# 110733                         H            N            N            N
# 110735                         U            N            N            N
# 110746                         H            N            Y            N
#
#        Cellphone
# 10             N
# 88             N
# 92             N
# 136            N
# 175            N
# ...          ...
# 110602         Y
# 110678         N
# 110733         N
# 110735         Y
# 110746         Y
#
# [4675 rows x 13 columns]

# %%
import numpy as np

# %%
data2 = df['personexactage'].replace(0, df_mean)

# %%
data2
# Out:
# 0         79
# 1         77
# 2         61
# 3         80
# 4         75
#           ..
# 110745    61
# 110746     0
# 110747    48
# 110748    44
# 110749    50
# Name: personexactage, Length: 110750, dtype: int64

# %%
df['personexactage'].head(20)
# Out:
# 0      79
# 1      77
# 2      61
# 3      80
# 4      75
# 5      47
# 6     101
# 7     101
# 8      53
# 9      62
# 10      0
# 11     56
# 12     56
# 13     56
# 14     60
# 15     32
# 16     66
# 17     80
# 18     34
# 19     62
# Name: personexactage, dtype: int64

# %%
data
# Out:
#         FullPhoneNumber state  personexactage IsMobile estimatedincomecode  \
# 10           9072771257    AK               0        F                   Q
# 88           9072432220    AK               0        F                   J
# 92           9072584757    AK               0        F                   S
# 136          9072434596    AK               0        F                   N
# 175          9073364672    AK               0        F                   O
# ...                 ...   ...             ...      ...                 ...
# 110602       9073988452    AK               0        T                   O
# 110678       9077478649    AK               0        F                   C
# 110733       9072226908    AK               0        F                   O
# 110735       9075909766    AK               0        T                   N
# 110746       9072327715    AK               0        T                   M
#
#        CreditRating NumberOfLinesOfCredit Credit_RangeOfNewCredit  \
# 10                D                     1                       4
# 88                D                     3                       U
# 92                B                     2                       U
# 136               D                     U                       U
# 175               C                     1                       7
# ...             ...                   ...                     ...
# 110602            B                     1                       7
# 110678            C                     U                       U
# 110733            C                     1                       7
# 110735            A                     U                       U
# 110746            C                     2                       U
#
#        homeownerprobabilitymodel Disconnected National DNC Internal DNC  \
# 10                             H            N            N            N
# 88                             H            N            N            N
# 92                             H            N            Y            N
# 136                            H            N            Y            N
# 175                            H            N            Y            N
# ...                          ...          ...          ...          ...
# 110602                         H            N            Y            N
# 110678                         H            N            Y            N
# 110733                         H            N            N            N
# 110735                         U            N            N            N
# 110746                         H            N            Y            N
#
#        Cellphone
# 10             N
# 88             N
# 92             N
# 136            N
# 175            N
# ...          ...
# 110602         Y
# 110678         N
# 110733         N
# 110735         Y
# 110746         Y
#
# [4675 rows x 13 columns]

# %%
data.head(20)
# Out:
#      FullPhoneNumber state  personexactage IsMobile estimatedincomecode  \
# 10        9072771257    AK               0        F                   Q
# 88        9072432220    AK               0        F                   J
# 92        9072584757    AK               0        F                   S
# 136       9072434596    AK               0        F                   N
# 175       9073364672    AK               0        F                   O
# 256       9072453441    AK               0        F                   Q
# 277       9078683266    AK               0        F                   Q
# 283       9075633399    AK               0        F                   U
# 310       9077701947    AK               0        F                   N
# 311       9077701947    AK               0        F                   N
# 312       9077701947    AK               0        F                   N
# 317       9075636781    AK               0        F                   Q
# 325       9072799885    AK               0        F                   O
# 333       9075620377    AK               0        F                   H
# 336       9072278177    AK               0        T                   C
# 337       9072278177    AK               0        T                   C
# 352       9075298815    AK               0        T                   F
# 389       9073332659    AK               0        F                   N
# 407       6239749330    AK               0        F                   G
# 464       9073372085    AK               0        F                   N
#
#     CreditRating NumberOfLinesOfCredit Credit_RangeOfNewCredit  \
# 10             D                     1                       4
# 88             D                     3                       U
# 92             B                     2                       U
# 136            D                     U                       U
# 175            C                     1                       7
# 256            C                     1                       5
# 277            B                     3                       U
# 283            U                     U                       U
# 310            B                     1                       7
# 311            B                     1                       7
# 312            B                     1                       7
# 317            E                     1                       6
# 325            A                     3                       7
# 333            C                     U                       U
# 336            E                     1                       4
# 337            E                     1                       4
# 352            F                     U                       U
# 389            A                     1                       7
# 407            U                     U                       U
# 464            B                     1                       6
#
#     homeownerprobabilitymodel Disconnected National DNC Internal DNC Cellphone
# 10                          H            N            N            N         N
# 88                          H            N            N            N         N
# 92                          H            N            Y            N         N
# 136                         H            N            Y            N         N
# 175                         H            N            Y            N         N
# 256                         H            N            Y            N         N
# 277                         H            N            N            N         N
# 283                         H            N            Y            N         N
# 310                         H            N            N            N         N
# 311                         H            N            N            N         N
# 312                         H            N            N            N         N
# 317                         H            N            N            N         N
# 325                         H            N            N            N         N
# 333                         H            N            Y            N         N
# 336                         H            N            Y            N         Y
# 337                         H            N            Y            N         Y
# 352                         H            N            N            N         Y
# 389                         H            N            Y            N         N
# 407                         U            Y            Y            N         N
# 464                         H            Y            N            N         N

# %%
data['personexactage'] = data['personexactage'].astype({'personexactage': int})
# Out:
# <ipython-input-37-0bddc13634ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['personexactage'] = data['personexactage'].astype({'personexactage': int})

# %%
data
# Out:
#         FullPhoneNumber state  personexactage IsMobile estimatedincomecode  \
# 10           9072771257    AK               0        F                   Q
# 88           9072432220    AK               0        F                   J
# 92           9072584757    AK               0        F                   S
# 136          9072434596    AK               0        F                   N
# 175          9073364672    AK               0        F                   O
# ...                 ...   ...             ...      ...                 ...
# 110602       9073988452    AK               0        T                   O
# 110678       9077478649    AK               0        F                   C
# 110733       9072226908    AK               0        F                   O
# 110735       9075909766    AK               0        T                   N
# 110746       9072327715    AK               0        T                   M
#
#        CreditRating NumberOfLinesOfCredit Credit_RangeOfNewCredit  \
# 10                D                     1                       4
# 88                D                     3                       U
# 92                B                     2                       U
# 136               D                     U                       U
# 175               C                     1                       7
# ...             ...                   ...                     ...
# 110602            B                     1                       7
# 110678            C                     U                       U
# 110733            C                     1                       7
# 110735            A                     U                       U
# 110746            C                     2                       U
#
#        homeownerprobabilitymodel Disconnected National DNC Internal DNC  \
# 10                             H            N            N            N
# 88                             H            N            N            N
# 92                             H            N            Y            N
# 136                            H            N            Y            N
# 175                            H            N            Y            N
# ...                          ...          ...          ...          ...
# 110602                         H            N            Y            N
# 110678                         H            N            Y            N
# 110733                         H            N            N            N
# 110735                         U            N            N            N
# 110746                         H            N            Y            N
#
#        Cellphone
# 10             N
# 88             N
# 92             N
# 136            N
# 175            N
# ...          ...
# 110602         Y
# 110678         N
# 110733         N
# 110735         Y
# 110746         Y
#
# [4675 rows x 13 columns]
