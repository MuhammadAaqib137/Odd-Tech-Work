# %%
import pandas as pd

# %%
data = pd.read_csv("data_for_ai_bot_master_6.csv")
data
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3475      am doing great so far how are you doing today
# 3476  well youd like to learn a little bit more info...
# 3477                                  about ten dollars
# 3478                                  no no ten dollars
# 3479           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
data['Bot Transcription'].duplicated().any()
# Out:
# True

# %%
data['Bot Transcription'].dtypes
# Out:
# dtype('O')

# %%
data['Bot Transcription'].astype(str)
# Out:
# 0                                                    a  i
# 1                                                la on we
# 2                     i dont know anything on credit card
# 3                                    what it why you call
# 4       seven three nine were not available to answer ...
#                               ...
# 3475        am doing great so far how are you doing today
# 3476    well youd like to learn a little bit more info...
# 3477                                    about ten dollars
# 3478                                    no no ten dollars
# 3479             ten dollars i just got gap the other day
# Name: Bot Transcription, Length: 3480, dtype: object

# %%
new_list=[x for x in data['Bot Transcription'].astype(str) if len(x)<2]

# %%
new_list
# Out:
# ['j', 'n', 'u', 'e', 's', 'a']

# %%
new = pd.DataFrame({'Bot Transcription':new_list})
new
# Out:
#   Bot Transcription
# 0                 j
# 1                 n
# 2                 u
# 3                 e
# 4                 s
# 5                 a

# %%
new_data = pd.merge(data, new, on=["Bot Transcription"], how="outer", indicator=True)

print(new_data)


new_data = new_data.loc[new_data["_merge"] == "left_only"].drop("_merge", axis=1)

print(new_data)
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3475      am doing great so far how are you doing today
# 3476  well youd like to learn a little bit more info...
# 3477                                  about ten dollars
# 3478                                  no no ten dollars
# 3479           ten dollars i just got gap the other day
#
#                                           Recording URL     _merge
# 0     http://192.168.88.254/transcription_wav/transc...  left_only
# 1     http://192.168.88.254/transcription_wav/transc...  left_only
# 2     http://192.168.88.254/transcription_wav/transc...  left_only
# ...

# %%
new_data
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3475      am doing great so far how are you doing today
# 3476  well youd like to learn a little bit more info...
# 3477                                  about ten dollars
# 3478                                  no no ten dollars
# 3479           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data['Bot Transcription'].duplicated().value_counts()
# Out:
# False    3469
# True        5
# Name: Bot Transcription, dtype: int64

# %%
new_data.drop_duplicates(subset ='Bot Transcription',keep=False,inplace=True)

# %%
new_data['Bot Transcription'].duplicated().value_counts()
# Out:
# False    3466
# Name: Bot Transcription, dtype: int64

# %%
new_data
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3475      am doing great so far how are you doing today
# 3476  well youd like to learn a little bit more info...
# 3477                                  about ten dollars
# 3478                                  no no ten dollars
# 3479           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data=new_data.reset_index(drop=True)

# %%
new_data
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3461      am doing great so far how are you doing today
# 3462  well youd like to learn a little bit more info...
# 3463                                  about ten dollars
# 3464                                  no no ten dollars
# 3465           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %% [markdown]
# # removing data having text after thge beep

# %%
junk = []
count = 1
for i in new_data['Bot Transcription'].astype(str):
    if ('after the be' in i)or('press' in i )or('a e e ' in i)or ('e e e' in i) or ('e  a a' in i)or('o o e' in i)or('a a a a' in i)or ('i o e' in i)or('h o e' in i)or('o o o o'in i) or ('a a a a'in i) :
        print('\n '+str(count)+ ' '+i)
        junk.append(i)
        count+=1
# Out:
#  1 right now if you wish to hold press pound
#
#  2 your name and phone number after the beak
#
#  3 a e e   h  o  a
#
#  4 amy torteriji press one for robert soon press too
#
#  5 please leave your name and l number after the been we will
#
#  6 please leave your name and phone number after the beepwel
#
#  7 by recorded for a free autoglassquote pressed one
#
#  8 in service need please press one
#
#  9 o o e a e
#
#  10 i o e
#
#  11 to reply your message press one an
#
#  12 o o e or re
#
#  13 please leave your name and phone number after the bear we will return
#
#  14 message when youve finished recording you may hang up or press one for more optionsto
#
#  15 ana a a a
#
#  16 to hear the message again press one to save the message you have just recorded pressed two to canceled a message and start again press three to record the message again press four to mark the messages urgent press five to mark the messages private press sixth for other contact option press pound you
#
# ...

# %%
junk
# Out:
# ['right now if you wish to hold press pound',
#  'your name and phone number after the beak',
#  'a e e   h  o  a',
#  'amy torteriji press one for robert soon press too',
#  'please leave your name and l number after the been we will',
#  'please leave your name and phone number after the beepwel',
#  'by recorded for a free autoglassquote pressed one',
#  'in service need please press one',
#  'o o e a e',
#  'i o e',
#  'to reply your message press one an',
#  'o o e or re',
#  'please leave your name and phone number after the bear we will return',
#  'message when youve finished recording you may hang up or press one for more optionsto',
#  'ana a a a',
#  'to hear the message again press one to save the message you have just recorded pressed two to canceled a message and start again press three to record the message again press four to mark the messages urgent press five to mark the messages private press sixth for other contact option press pound you',
# ...

# %%
df_rmv_beep = new_data

for i in junk:
    df_rmv_beep = df_rmv_beep[df_rmv_beep['Bot Transcription'] != i]

# %%
df_rmv_beep
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3461      am doing great so far how are you doing today
# 3462  well youd like to learn a little bit more info...
# 3463                                  about ten dollars
# 3464                                  no no ten dollars
# 3465           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
df_rmv_beep=df_rmv_beep.reset_index(drop=True)

# %%
df_rmv_beep
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3277      am doing great so far how are you doing today
# 3278  well youd like to learn a little bit more info...
# 3279                                  about ten dollars
# 3280                                  no no ten dollars
# 3281           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk1 = []
count = 0
for i in df_rmv_beep['Bot Transcription'].astype(str):
    if ('connected 'in i) or ('disconnected 'in i) or ( 'pound'  in i)or('voicemail'in i)or('record your message' in i):
        print('\n '+str(count)+ ' '+i)
        junk1.append(i)
        count+=1
# Out:
#  0 two six oil nine six six one has been disconnected the number three six zero two six zero nine six six one has been disconnected no further information is available about this number
#
#  1 row six nine six we leave a message and i will return your call as soon as i can at the tone please record your message when you have finished
#
#  2 at the tone please record your message when you finished rear
#
#  3 add the telleand please record your message when you finished i
#
#  4 few ms again at the tone please record your message when youve finished recording you may hang up or with one for more nations
#
#  5 at the tone please record your message when you have finished recall
#
#  6 at the tone please record your message when you have i
#
#  7 the call has been forwarded to the voicemail for engineering associates no one is a
#
#  8 toll call now at the tone please record your message when you have been
#
#  9 no at the tone please record your message when you have
#
# ...

# %%
noise_remv=df_rmv_beep

for i in junk1:
    noise_remv = noise_remv[noise_remv['Bot Transcription'] != i]

# %%
noise_remv
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3277      am doing great so far how are you doing today
# 3278  well youd like to learn a little bit more info...
# 3279                                  about ten dollars
# 3280                                  no no ten dollars
# 3281           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
noise_remv=noise_remv.reset_index(drop=True)

# %%
noise_remv
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3242      am doing great so far how are you doing today
# 3243  well youd like to learn a little bit more info...
# 3244                                  about ten dollars
# 3245                                  no no ten dollars
# 3246           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk2 = []
count = 0
for i in df_rmv_beep['Bot Transcription'].astype(str):
    if ('avalaible'in i) or ('hospital'in i) or ( 'hang up'  in i)or('mailbox'in i)or('thankyou ' in i)or('a a a' in i)or ('e e a' in i):
        print('\n '+str(count)+ ' '+i)
        junk2.append(i)
        count+=1
# Out:
#  0 leo  a a on an an an ha a a
#
#  1 one two four four five five three six nine is not available the mailbox is full and cannot accept any messages at this time good bye
#
#  2 few ms again at the tone please record your message when youve finished recording you may hang up or with one for more nations
#
#  3 hello hellodon i got it sky hang up
#
#  4 please try again the first three letters of the last name on this prescription are e a
#
#  5 one four nine five two five four two seven is not available the mailbox is full and cannot accept any messages at this time good bye
#
#  6 available the mailbox is full and cannot accept any messages at this time good bye
#
#  7 no now e hang up unite record
#
#  8 i would if i had any a a a debt i i went through the eighties and nineties and ah that taught me a very hard lesson so i am no longer in debt im im taking care my up money very well thank you done
#
# ...

# %%
#4 6 8 9
unwanted = [4, 6,8, 9]
 
for ele in sorted(unwanted, reverse = True):
    del junk2[ele]

# %%
len(junk2)
# Out:
# 26

# %%
noise_remv1=noise_remv

for i in junk2:
    noise_remv1 = noise_remv1[noise_remv1['Bot Transcription'] != i]

# %%
noise_remv1
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3242      am doing great so far how are you doing today
# 3243  well youd like to learn a little bit more info...
# 3244                                  about ten dollars
# 3245                                  no no ten dollars
# 3246           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
noise_remv1=noise_remv1.reset_index(drop=True)

# %%
noise_remv1
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3218      am doing great so far how are you doing today
# 3219  well youd like to learn a little bit more info...
# 3220                                  about ten dollars
# 3221                                  no no ten dollars
# 3222           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk3 = []
count = 0
for i in noise_remv1['Bot Transcription'].astype(str):
    if  ('nor sivimo'in i) or ( 'if youre ready'  in i)or('and what company are you with'in i)or('thankyou ' in i)or('o a o' in i)or (' o o' in i):
        print('\n '+str(count)+ ' '+i)
        junk3.append(i)
        count+=1
# Out:
#  0 nor sivimo s men sakipurkustet noestawa orlando oporuna malaconics unto milsusteman parariskonictar or myluno paragabalsu message pope don
#
#  1 nor sivimo s men sakiporkutet noetawa orlando oporuna malaconics once mikestema parariskonictar or myluno pararabalsumensaki pope don
#
#  2 nor sivimo s men sakipurkustet noestawa orlando oporuna malaconics unto milsusteman parariskonictar or myluno peragabalsu mensaki pope don
#
#  3 to at in  o of be o
#
#  4 he he he ho h h to to ha in o of ho a
#
#  5 if youre ready say ready or pray keen
#
#  6 if youre ready say ready book its any key
#
#  7 o o on a o he the
#
#  8 acre mi o o drinkthen may for
#
#  9 okay and what company are you with jane
#
#  10 and what company are you with jane
#
#  11 and what company are you with
#
#  12 and what company are you with ame
#
#  13 and what company are you with james
#
#  14 he o of a   the
#
#  15 oo o o
#
#  16 o o i o own nobody and i dont want nobody calling me thank you
#
# ...

# %%
unwanted1 = [9,13,17,18,23,24]
 
for ele in sorted(unwanted1, reverse = True):
    del junk3[ele]

# %%
junk3
# Out:
# ['nor sivimo s men sakipurkustet noestawa orlando oporuna malaconics unto milsusteman parariskonictar or myluno paragabalsu message pope don',
#  'nor sivimo s men sakiporkutet noetawa orlando oporuna malaconics once mikestema parariskonictar or myluno pararabalsumensaki pope don',
#  'nor sivimo s men sakipurkustet noestawa orlando oporuna malaconics unto milsusteman parariskonictar or myluno peragabalsu mensaki pope don',
#  'to at in  o of be o',
#  'he he he ho h h to to ha in o of ho a',
#  'if youre ready say ready or pray keen',
#  'if youre ready say ready book its any key',
#  'o o on a o he the',
#  'acre mi o o drinkthen may for',
#  'and what company are you with jane',
#  'and what company are you with',
#  'and what company are you with ame',
#  'he o of a   the',
#  'oo o o',
#  'o o i o own nobody and i dont want nobody calling me thank you',
#  'yes dose the o o t z y macdougl m a c d o u g a l but macdogl',
# ...

# %%
#9,13,17,18,23,24
#recording, nor sivimo,if youre ready, and what company are you with,o a o

# %%
noise_remv2=noise_remv1

for i in junk3:
    noise_remv2 = noise_remv2[noise_remv2['Bot Transcription'] != i]

# %%
 noise_remv2
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3218      am doing great so far how are you doing today
# 3219  well youd like to learn a little bit more info...
# 3220                                  about ten dollars
# 3221                                  no no ten dollars
# 3222           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
noise_remv2=noise_remv2.reset_index(drop=True)

# %%
noise_remv2.to_csv (r'Z:\Muhammad Aaqib\Cleaned_CSV.csv', index=None)

# %%
#
unwanted_data_index=[0, 31,127,202,289,307,415,495,498,545,564,575,623,629,647,658,730,732,781,837,852,880,881, 915, 916, 924, 925,997,1054,1004,1094,1138,1228,1231,1260,1380, 1418, 1420,1422,1463,1464,1472,1473,1484,1549,
1556,1567,1594,1595,1608,1770]
unwanted_data =[]
for i in unwanted_data_index:
    unwanted_data.append(noise_remv2['Bot Transcription'][i])
unwanted_data
# Out:
# ['a  i',
#  'leo',
#  'ha o at ta a',
#  'e   e',
#  'a e po',
#  'yhveev c a o a bad vol',
#  'du',
#  'are up',
#  'a ha',
#  'him now',
#  'e h',
#  'e he a',
#  'e mon',
#  'c h i go',
#  'o mo',
#  'to continue this call in english paracondinnoir in nizpagnol prefuone  number',
#  'le',
#  'onte',
#  'vandeamon row mo n r o a',
#  'to   o ha oh ta',
#  'a  ta',
#  'cobrolamo colombian hath appototari e open texan accompli ajonantaicaparonta a local apontutio poemooevagoon wapiaocomi ennaamida tovaluit capital legotian cticula ahagaogaibema etawao belaya is state early between the senator dieelyointe a before',
#  'iamoemaiogeol elaborated  ineiopolitia all day allot rebuliha to material santo even aoteaste equal indeed delamaderaa encoberhar by rhetor on teovemon gate e cocatoranof petrov planting into  aliopatiaepecaprala of amopocoalli arena inairatotoabotranintoadeolapea kept olaparaa',
#  'e o a',
#  'po to',
#  'om o',
#  'o me',
#  'en a',
#  'e  o',
#  'e  ha',
# ...

# %%
#removing this above data 
noise_remv3=noise_remv2
for i in unwanted_data:
    noise_remv3 = noise_remv3[noise_remv3['Bot Transcription'] != i]
#e o a,service

# %%
noise_remv3
# Out:
#                                       Bot Transcription  \
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# 5     thank you record o mead a massage of commerce ...
# ...                                                 ...
# 3196      am doing great so far how are you doing today
# 3197  well youd like to learn a little bit more info...
# 3198                                  about ten dollars
# 3199                                  no no ten dollars
# 3200           ten dollars i just got gap the other day
#
#                                           Recording URL
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# 4     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
noise_remv3=noise_remv3.reset_index(drop=True)

# %%
noise_remv3
# Out:
#                                       Bot Transcription  \
# 0                                              la on we
# 1                   i dont know anything on credit card
# 2                                  what it why you call
# 3     seven three nine were not available to answer ...
# 4     thank you record o mead a massage of commerce ...
# ...                                                 ...
# 3145      am doing great so far how are you doing today
# 3146  well youd like to learn a little bit more info...
# 3147                                  about ten dollars
# 3148                                  no no ten dollars
# 3149           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
noise_remv3.to_csv (r'Z:\Muhammad Aaqib\Cleaned_CSV.csv', index=None)

# %%
junk4 = []
count = 0
for i in noise_remv3['Bot Transcription'].astype(str):
    if  ('service '  in i) or ('       ' in i):
        print('\n '+str(count)+ ' '+i)
        junk4.append(i)
        count+=1
del junk4[8]
# Out:
#  0 welcome to the frontier voice essaying service to leave
#
#  1 five five zero three nine four is in service please try your call again two zero eight eight five five zero three nine four is in service please try your call again
#
#  2 herein no longer in service if you
#
#  3 and you reached of using a screening service from goose and will get a recording and transcribe of this call
#
#  4 all of our representatives are assisting other colles rather than have you wait on hold we can call you back when its your turn between eight and nine from now you will not lose your place in line if you choose to use the service to receive
#
#  5 sorry this service is not available right now thank you for calling good bye
#
#  6 please note fed regulations require that you make a phone call send a text message or go online every thirty days with your phone to keep your lifetime service active
#
#  7 thank you for calling for service please plus one
#
# ...

# %%
noise_remv4=noise_remv3
for i in junk4:
    noise_remv4 = noise_remv4[noise_remv4['Bot Transcription'] != i]
noise_remv4
# Out:
#                                       Bot Transcription  \
# 0                                              la on we
# 1                   i dont know anything on credit card
# 2                                  what it why you call
# 3     seven three nine were not available to answer ...
# 4     thank you record o mead a massage of commerce ...
# ...                                                 ...
# 3145      am doing great so far how are you doing today
# 3146  well youd like to learn a little bit more info...
# 3147                                  about ten dollars
# 3148                                  no no ten dollars
# 3149           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
noise_remv4=noise_remv4.reset_index(drop=True)

# %%
noise_remv4.to_csv (r'Z:\Muhammad Aaqib\Cleaned_CSV.csv', index=None)

# %%
unwanted_data1_index=[1750,1752,1759,1762,1956,1964,2002,2055,2092,2096,2105,2117,2166,2171,2219,
2264,2270,2324,2327,2328,2367,2432,2444,2458,2506,2511,2517,2540,2558,2575,2654,
2658,2662,2666,2667,2668,2683,2700,2730,2752,2758,2776,2814,2857,2913,2918,2937,
2943,2946,2948,3073]
unwanted_data1 =[]
for i in unwanted_data1_index:
    unwanted_data1.append(noise_remv4['Bot Transcription'][i])
unwanted_data1
# Out:
# ['it to o ai o',
#  'o a he o',
#  'a i he',
#  'i o a',
#  'o t',
#  'a  o  etc',
#  'erie a',
#  'wat  oo',
#  'ha',
#  'li do',
#  're on',
#  'isn',
#  'a e i',
#  'i a  al',
#  'at ce',
#  'a om',
#  'ago o an an on',
#  'e oo o ha the',
#  'you o pa',
#  'oh or oe',
#  'o o the',
#  'wo',
#  'the to  o',
#  'marahada',
#  'he ta',
#  'to o h a no',
#  'of a   a a e a',
#  'o ta  o',
#  'etat e a be',
#  'a a  i',
#  nan,
#  'an am',
#  'te o  odor',
#  'h ar to t',
#  'e oh no',
#  'il',
#  'i ah',
#  'i a o',
#  'to o',
#  'e he e',
#  'i i or  e co clay',
#  'leo o   n had i and a ta',
#  'on de',
#  'h no',
#  'a    i',
#  'iii to',
#  'oh five four eight please leave the message and some one will return your call as soon as possible thank you and have a good day',
#  'a  a i here',
#  'the m',
#  'to  de',
#  'e a tactical into']

# %%
noise_remv5=noise_remv4
for i in unwanted_data1:
    noise_remv5 = noise_remv5[noise_remv5['Bot Transcription'] != i]

# %%
noise_remv5  = noise_remv5.reset_index(drop=True)

# %%
noise_remv5
# Out:
#                                       Bot Transcription  \
# 0                                              la on we
# 1                   i dont know anything on credit card
# 2                                  what it why you call
# 3     seven three nine were not available to answer ...
# 4     thank you record o mead a massage of commerce ...
# ...                                                 ...
# 3086      am doing great so far how are you doing today
# 3087  well youd like to learn a little bit more info...
# 3088                                  about ten dollars
# 3089                                  no no ten dollars
# 3090           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk5 = []
count = 0
for i in noise_remv5['Bot Transcription'].astype(str):
    if  ('emergency'in i) or('will return your CALL' in i )or('for quality assurance' in i)or('able to answer'in i)or ('training' in i )or('after the tone'in i)or ('AT the tone'in i ) or('after recording' in i)or ('after ring' in i):
        print('\n '+str(count)+ ' '+i)
        junk5.append(i)
        count+=1
# Out:
#  0 seven three nine were not available to answer the phone right now so if you leave a message and will get back to you thanks y
#
#  1 less leave a message after the tone
#
#  2 sorry we were not able to answer your phone call
#
#  3 after the tone
#
#  4 sanctioning and remarking leader were currently closed monday through friday eighth a m to five p m after the tone please leave a detailed message and we will return your call the next business day
#
#  5 at sero eight three four seven six five three one please began to leave a message after the tone and ill return your call as soon as i am able to thank you and have a great day
#
#  6 hill please leave the message after the tone
#
#  7 if this is at an emergency leave dial
#
# ...

# %%
noise_remv6=noise_remv5
for i in junk5:
    noise_remv6 = noise_remv6[noise_remv6['Bot Transcription'] != i]
noise_remv6
# Out:
#                                       Bot Transcription  \
# 0                                              la on we
# 1                   i dont know anything on credit card
# 2                                  what it why you call
# 4     thank you record o mead a massage of commerce ...
# 5             youre buying forgetting my rackento basal
# ...                                                 ...
# 3086      am doing great so far how are you doing today
# 3087  well youd like to learn a little bit more info...
# 3088                                  about ten dollars
# 3089                                  no no ten dollars
# 3090           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 4     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
noise_remv6= noise_remv6.reset_index(drop=True)
noise_remv6
# Out:
#                                       Bot Transcription  \
# 0                                              la on we
# 1                   i dont know anything on credit card
# 2                                  what it why you call
# 3     thank you record o mead a massage of commerce ...
# 4             youre buying forgetting my rackento basal
# ...                                                 ...
# 3075      am doing great so far how are you doing today
# 3076  well youd like to learn a little bit more info...
# 3077                                  about ten dollars
# 3078                                  no no ten dollars
# 3079           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
junk6 = []
count = 0
for i in noise_remv6['Bot Transcription'].astype(str):
    if  ('leave your' in i):
        print('\n '+str(count)+ ' '+i)
        junk6.append(i)
        count+=1
# Out:
#  0 no pity productions aunt a all right now but if you leave your name and number ill return your called o the possible thanks have a great day aet
#
#  1 and shelled please leave your message now
#
#  2 notify you leave your name and number ill call you back just as soon as possible thank you
#
#  3 leave your name your phone number and a brief message and will go back to you as soon as we can thank you
#
#  4 git thank you so much for calling im so sorry i cannot personally answer right now but please at the sound of the tone leave your name your number and the purpose of your call and ill get back to you as immediately as possible thank you and have a wonderful day
#
#  5 your business f reached this methode during normal business hour commedeater assisting another customer or running a peace in macanre cannot hear the foam your business is very important please leave your named phone number and hell call you back if thesis possible thank and had a great day
#
# ...

# %%
noise_remv7=noise_remv6
for i in junk6:
    noise_remv7 = noise_remv7[noise_remv7['Bot Transcription'] != i]
noise_remv7
# Out:
#                                       Bot Transcription  \
# 0                                              la on we
# 1                   i dont know anything on credit card
# 2                                  what it why you call
# 3     thank you record o mead a massage of commerce ...
# 4             youre buying forgetting my rackento basal
# ...                                                 ...
# 3075      am doing great so far how are you doing today
# 3076  well youd like to learn a little bit more info...
# 3077                                  about ten dollars
# 3078                                  no no ten dollars
# 3079           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
noise_remv7= noise_remv7.reset_index(drop=True)

# %%
noise_remv7.to_csv (r'Z:\Muhammad Aaqib\Cleaned_CSV.csv', index=None)

# %% [markdown]
# # to be continued

# %%
# number_list = ["zero",'one', 'two', 'three', 'four', 'five','six','seven','eight','nine','ten']
# num_com=[]
# import itertools
# for a, b in itertools.combinations(number_list, 2):
#     num_com.append(a+' '+b)

# %%
#  num_com

# %%
# hospital, mailbox, avalaible, hang up, thankyou for call,

# %%
# junk2 = []
# count=0
# for i in  num_com:
#     for x in noise_remv['Bot Transcription'].astype(str):
#         if i in x:
#             junk2.append(x)
#             print(str(count)+' '+x)
#             count+=1

# %%
# junk2=list(set(junk2))
# count = 0 
# for i in junk2:
#     print(str(count)+' '+i)
#     count+=1

# %%
#21 59

# %%
# noise_remv

# %%
# #16 27 43 51
# junk2

# %%
# number_list = ["zero",'one', 'two', 'three', 'four', 'five','six','seven','eight','nine','ten']
# import itertools
# for a, b in itertools.combinations(number_list, 2):
#     print(a,b)

# new code

# number_list = ["zero",'one', 'two', 'three', 'four', 'five','six','seven','eight','nine','ten']
# # df3 = df2.copy()
# import itertools
# for a, b in itertools.combinations(number_list, 2):
#     df3 =pd.DataFrame(df2[df2['Bot Transcription'].str.contains(a,b)])


# after the bee'
# ' oo '
# ' o o '
# ' press '
# ' e o '
# ' e e '

# # record your message
# # finished recording
# # voicemail
# # please record your message after the been when youre finished you may hang up or press pound to review or we record your message
# # message
# # finished
# # recording
# # hang up
# # for more option
# # gave a message and ill get back to you shortly
# # connected
