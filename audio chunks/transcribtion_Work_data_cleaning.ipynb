# %%
import pandas as pd

# %%
data = pd.read_csv("data_for_ai_bot_master_6.csv")
data
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3475      am doing great so far how are you doing today
# 3476  well youd like to learn a little bit more info...
# 3477                                  about ten dollars
# 3478                                  no no ten dollars
# 3479           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
data['Bot Transcription'].duplicated().any()
# Out:
# True

# %%
data['Bot Transcription'].dtypes
# Out:
# dtype('O')

# %%
data['Bot Transcription'].astype(str)
# Out:
# 0                                                    a  i
# 1                                                la on we
# 2                     i dont know anything on credit card
# 3                                    what it why you call
# 4       seven three nine were not available to answer ...
#                               ...
# 3475        am doing great so far how are you doing today
# 3476    well youd like to learn a little bit more info...
# 3477                                    about ten dollars
# 3478                                    no no ten dollars
# 3479             ten dollars i just got gap the other day
# Name: Bot Transcription, Length: 3480, dtype: object

# %%
new_list=[x for x in data['Bot Transcription'].astype(str) if len(x)<2]

# %%
new_list
# Out:
# ['j', 'n', 'u', 'e', 's', 'a']

# %%
new = pd.DataFrame({'Bot Transcription':new_list})
new
# Out:
#   Bot Transcription
# 0                 j
# 1                 n
# 2                 u
# 3                 e
# 4                 s
# 5                 a

# %%
# new_data = pd.merge(data, new, on=["Bot Transcription"], how="outer", indicator=True)

# print(new_data)


# new_data = new_data.loc[new_data["_merge"] == "left_only"].drop("_merge", axis=1)

# print(new_data)
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3475      am doing great so far how are you doing today
# 3476  well youd like to learn a little bit more info...
# 3477                                  about ten dollars
# 3478                                  no no ten dollars
# 3479           ten dollars i just got gap the other day
#
#                                           Recording URL     _merge
# 0     http://192.168.88.254/transcription_wav/transc...  left_only
# 1     http://192.168.88.254/transcription_wav/transc...  left_only
# 2     http://192.168.88.254/transcription_wav/transc...  left_only
# ...

# %%
new_data
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3475      am doing great so far how are you doing today
# 3476  well youd like to learn a little bit more info...
# 3477                                  about ten dollars
# 3478                                  no no ten dollars
# 3479           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data['Bot Transcription'].duplicated().value_counts()
# Out:
# False    3469
# True        5
# Name: Bot Transcription, dtype: int64

# %%
new_data.drop_duplicates(subset ='Bot Transcription',keep=False,inplace=True)

# %%
new_data['Bot Transcription'].duplicated().value_counts()
# Out:
# False    3466
# Name: Bot Transcription, dtype: int64

# %%
new_data
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3475      am doing great so far how are you doing today
# 3476  well youd like to learn a little bit more info...
# 3477                                  about ten dollars
# 3478                                  no no ten dollars
# 3479           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data=new_data.reset_index(drop=True)

# %%
new_data
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3461      am doing great so far how are you doing today
# 3462  well youd like to learn a little bit more info...
# 3463                                  about ten dollars
# 3464                                  no no ten dollars
# 3465           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %% [markdown]
# # removing data having text after thge beep

# %%
junk = []
count = 1
for i in new_data['Bot Transcription'].astype(str):
    if ('after the be' in i)or('press' in i )or('a e e ' in i)or ('e e e' in i) or ('e  a a' in i)or('o o e' in i)or('a a a a' in i)or ('i o e' in i)or('h o e' in i)or('o o o o'in i) or ('a a a a'in i) :
        print('\n '+str(count)+ ' '+i)
        junk.append(i)
        count+=1
# Out:
#  1 right now if you wish to hold press pound
#
#  2 your name and phone number after the beak
#
#  3 a e e   h  o  a
#
#  4 amy torteriji press one for robert soon press too
#
#  5 please leave your name and l number after the been we will
#
#  6 please leave your name and phone number after the beepwel
#
#  7 by recorded for a free autoglassquote pressed one
#
#  8 in service need please press one
#
#  9 o o e a e
#
#  10 i o e
#
#  11 to reply your message press one an
#
#  12 o o e or re
#
#  13 please leave your name and phone number after the bear we will return
#
#  14 message when youve finished recording you may hang up or press one for more optionsto
#
#  15 ana a a a
#
#  16 to hear the message again press one to save the message you have just recorded pressed two to canceled a message and start again press three to record the message again press four to mark the messages urgent press five to mark the messages private press sixth for other contact option press pound you
#
# ...

# %%
junk
# Out:
# ['right now if you wish to hold press pound',
#  'your name and phone number after the beak',
#  'a e e   h  o  a',
#  'amy torteriji press one for robert soon press too',
#  'please leave your name and l number after the been we will',
#  'please leave your name and phone number after the beepwel',
#  'by recorded for a free autoglassquote pressed one',
#  'in service need please press one',
#  'o o e a e',
#  'i o e',
#  'to reply your message press one an',
#  'o o e or re',
#  'please leave your name and phone number after the bear we will return',
#  'message when youve finished recording you may hang up or press one for more optionsto',
#  'ana a a a',
#  'to hear the message again press one to save the message you have just recorded pressed two to canceled a message and start again press three to record the message again press four to mark the messages urgent press five to mark the messages private press sixth for other contact option press pound you',
# ...

# %%
df_rmv_beep = new_data

for i in junk:
    df_rmv_beep = df_rmv_beep[df_rmv_beep['Bot Transcription'] != i]

# %%
df_rmv_beep
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3461      am doing great so far how are you doing today
# 3462  well youd like to learn a little bit more info...
# 3463                                  about ten dollars
# 3464                                  no no ten dollars
# 3465           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
rem_Af_the_dataframe = pd.DataFrame({'Bot Transcription':rem_Af_the_bee}) 
rem_Af_the_dataframe
# Out:
#                                     Bot Transcription
# 0           your name and phone number after the beak
# 1   please leave your name and l number after the ...
# 2   please leave your name and phone number after ...
# 3   please leave your name and phone number after ...
# 4   give your name and phone number after the been...
# ..                                                ...
# 66  please leave your name and bone number after t...
# 67           anna phone number after the been we will
# 68              phone number after the been we will e
# 69  five is not available please leave a voicemail...
# 70  in en phone number after the bear we will reached
#
# [71 rows x 1 columns]

# %%
new_data1 = pd.merge( new_data,rem_Af_the_dataframe, on=["Bot Transcription"], how="outer", indicator=True)

print(new_data1)


new_data1 = new_data1.loc[new_data1["_merge"] == "left_only"].drop("_merge", axis=1)

print(new_data1)
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3461      am doing great so far how are you doing today
# 3462  well youd like to learn a little bit more info...
# 3463                                  about ten dollars
# 3464                                  no no ten dollars
# 3465           ten dollars i just got gap the other day
#
#                                           Recording URL     _merge
# 0     http://192.168.88.254/transcription_wav/transc...  left_only
# 1     http://192.168.88.254/transcription_wav/transc...  left_only
# 2     http://192.168.88.254/transcription_wav/transc...  left_only
# ...

# %%
new_data1
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3461      am doing great so far how are you doing today
# 3462  well youd like to learn a little bit more info...
# 3463                                  about ten dollars
# 3464                                  no no ten dollars
# 3465           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data1=new_data1.reset_index(drop=True)

# %%
new_data1
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3390      am doing great so far how are you doing today
# 3391  well youd like to learn a little bit more info...
# 3392                                  about ten dollars
# 3393                                  no no ten dollars
# 3394           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %% [markdown]
# # Removing sentance having keyword press

# %%
# rem_press_button = [] # 0 7 43
# count = 1
# for i in new_data1['Bot Transcription'].astype(str):
#     if 'press ' in i:
#         print('\n '+str(count)+ ' '+i)
#         rem_press_button.append(i)
#         count+=1

# %%
rem_press_button
# Out:
# ['right now if you wish to hold press pound',
#  'amy torteriji press one for robert soon press too',
#  'in service need please press one',
#  'to reply your message press one an',
#  'message when youve finished recording you may hang up or press one for more optionsto',
#  'to hear the message again press one to save the message you have just recorded pressed two to canceled a message and start again press three to record the message again press four to mark the messages urgent press five to mark the messages private press sixth for other contact option press pound you',
#  'please record your message when you have finished recording simply hang up or press pound for further option',
#  'but the tell plea record method that you finished report may hang out or bees one order to leave a callback number press five',
#  'we didnt get your message either because you were not speaking or because of a bacinagan sa to discannact to pressed one to record your message press tough',
# ...

# %%
rem_press_dataframe = pd.DataFrame({'Bot Transcription':rem_press_button})

# %%
new_data2 = pd.merge( new_data1,rem_press_dataframe, on=["Bot Transcription"], how="outer", indicator=True)

print(new_data2)


new_data2 = new_data2.loc[new_data2["_merge"] == "left_only"].drop("_merge", axis=1)

print(new_data2)
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3390      am doing great so far how are you doing today
# 3391  well youd like to learn a little bit more info...
# 3392                                  about ten dollars
# 3393                                  no no ten dollars
# 3394           ten dollars i just got gap the other day
#
#                                           Recording URL     _merge
# 0     http://192.168.88.254/transcription_wav/transc...  left_only
# 1     http://192.168.88.254/transcription_wav/transc...  left_only
# 2     http://192.168.88.254/transcription_wav/transc...  left_only
# ...

# %%
new_data2 = new_data2.reset_index(drop = True )

# %%
new_data2
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3310      am doing great so far how are you doing today
# 3311  well youd like to learn a little bit more info...
# 3312                                  about ten dollars
# 3313                                  no no ten dollars
# 3314           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %% [markdown]
# # saving into csv

# %%
new_data2.to_csv (r'Z:\Muhammad Aaqib\Cleaned_CSV.csv', index=None)

# %% [markdown]
# # Removing text having a a in string and oo

# %%
rem_a_o = [] # 0 7 43
count = 1
for i in new_data2['Bot Transcription'].astype(str):
    if # ('o o o o'in i) or ('a a a a'in i)  :
        print('\n '+str(count)+ ' '+i)
        rem_a_o.append(i)
        count+=1
# Out:
#  1 ana a a a
#
#  2 o o o o oe
#
#  3 oo o o o  he
#
#  4 e o o o o o o
#
#  5 o o o o e e
#
#  6 he a i a a a a a hen he he e the
#
#  7 vein a a a a an had an a here
#
#  8 a a a a an a o hot e a
#
#  9 a a a a a a a he
#
#  10 a a a a a at o
#
#  11 o o o o o  e
#
#  12 o o o oo
#
#  13 e an in  a a a a a t at hi heh
#
#  14 o o o o e he
#
#  15 o o o o o

# %% [markdown]
# # removing oooo

# %%
new_data3 = pd.merge( new_data2,rem_o_dataframe, on=["Bot Transcription"], how="outer", indicator=True)

print(new_data3)


new_data3 = new_data3.loc[new_data3["_merge"] == "left_only"].drop("_merge", axis=1)

print(new_data3)
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3310      am doing great so far how are you doing today
# 3311  well youd like to learn a little bit more info...
# 3312                                  about ten dollars
# 3313                                  no no ten dollars
# 3314           ten dollars i just got gap the other day
#
#                                           Recording URL     _merge
# 0     http://192.168.88.254/transcription_wav/transc...  left_only
# 1     http://192.168.88.254/transcription_wav/transc...  left_only
# 2     http://192.168.88.254/transcription_wav/transc...  left_only
# ...

# %%
new_data3
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3310      am doing great so far how are you doing today
# 3311  well youd like to learn a little bit more info...
# 3312                                  about ten dollars
# 3313                                  no no ten dollars
# 3314           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data3 = new_data3.reset_index(drop = True )
new_data3
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3295      am doing great so far how are you doing today
# 3296  well youd like to learn a little bit more info...
# 3297                                  about ten dollars
# 3298                                  no no ten dollars
# 3299           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data3.to_csv (r'Z:\Muhammad Aaqib\Cleaned_CSV.csv', index=None)

# %%
rem_aa = [] # 0 7 43
count = 1
for i in new_data3['Bot Transcription'].astype(str):
   # if ('a e e ' in i)or ('e e e' in i) or ('e  a a' in i)or('o o e' in i)or('a a a a' in i)or ('i o e' in i)or('h o e' in i) :
        print('\n '+str(count)+ ' '+i)
        rem_aa.append(i)
        count+=1
# Out:
#  1 a e e   h  o  a
#
#  2 o o e a e
#
#  3 i o e
#
#  4 o o e or re
#
#  5 aren etre e e teeth te e e te e e
#
#  6 i o e o o
#
#  7 e  a a   a e
#
#  8 are  a an o e a hat he a
#
#  9 e  a a a o  h  hot o he he
#
#  10 te  a  o a e  e o  e  to  e one oe  e e   e     eeeoooe   a  e he e e o a   see      a e e to one a he e e  a o a to a e oe  a  e  e see to e e a to  a e e   been       oo oo e a o    o             e       o     o e o     e    a e a e    e a  e  e  e  a e    e toe a eat e       e    a   e e oe a    o a  o  to a  e
#
#  11 the to o enter

# %%
rem_aa_dataframe = pd.DataFrame({'Bot Transcription':rem_aa}) 
rem_aa_dataframe
# Out:
#                                     Bot Transcription
# 0                                     a e e   h  o  a
# 1                                           o o e a e
# 2                                               i o e
# 3                                         o o e or re
# 4                   aren etre e e teeth te e e te e e
# 5                                           i o e o o
# 6                                        e  a a   a e
# 7                            are  a an o e a hat he a
# 8                          e  a a a o  h  hot o he he
# 9   te  a  o a e  e o  e  to  e one oe  e e   e   ...
# 10                                     the to o enter

# %%
new_data4 = pd.merge( new_data3,rem_aa_dataframe, on=["Bot Transcription"], how="outer", indicator=True)

print(new_data4)


new_data4 = new_data4.loc[new_data4["_merge"] == "left_only"].drop("_merge", axis=1)

print(new_data4)
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3295      am doing great so far how are you doing today
# 3296  well youd like to learn a little bit more info...
# 3297                                  about ten dollars
# 3298                                  no no ten dollars
# 3299           ten dollars i just got gap the other day
#
#                                           Recording URL     _merge
# 0     http://192.168.88.254/transcription_wav/transc...  left_only
# 1     http://192.168.88.254/transcription_wav/transc...  left_only
# 2     http://192.168.88.254/transcription_wav/transc...  left_only
# ...

# %%
new_data4
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3295      am doing great so far how are you doing today
# 3296  well youd like to learn a little bit more info...
# 3297                                  about ten dollars
# 3298                                  no no ten dollars
# 3299           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data4 = new_data4.reset_index(drop = True )
new_data4
# Out:
#                                       Bot Transcription  \
# 0                                                  a  i
# 1                                              la on we
# 2                   i dont know anything on credit card
# 3                                  what it why you call
# 4     seven three nine were not available to answer ...
# ...                                                 ...
# 3284      am doing great so far how are you doing today
# 3285  well youd like to learn a little bit more info...
# 3286                                  about ten dollars
# 3287                                  no no ten dollars
# 3288           ten dollars i just got gap the other day
#
#                                           Recording URL
# 0     http://192.168.88.254/transcription_wav/transc...
# 1     http://192.168.88.254/transcription_wav/transc...
# 2     http://192.168.88.254/transcription_wav/transc...
# 3     http://192.168.88.254/transcription_wav/transc...
# ...

# %%
new_data4.to_csv (r'Z:\Muhammad Aaqib\Cleaned_CSV.csv', index=None)

# %%
junk1
# Out:
# ['right now if you wish to hold press pound',
#  'your name and phone number after the beak',
#  'a e e   h  o  a',
#  'amy torteriji press one for robert soon press too',
#  'please leave your name and l number after the been we will',
#  'please leave your name and phone number after the beepwel',
#  'by recorded for a free autoglassquote pressed one',
#  'in service need please press one',
#  'o o e a e',
#  'i o e',
#  'to reply your message press one an',
#  'o o e or re',
#  'please leave your name and phone number after the bear we will return',
#  'message when youve finished recording you may hang up or press one for more optionsto',
#  'ana a a a',
#  'to hear the message again press one to save the message you have just recorded pressed two to canceled a message and start again press three to record the message again press four to mark the messages urgent press five to mark the messages private press sixth for other contact option press pound you',
# ...

# %%
df_rmv_beep = df_new

for i in junk:
    df_rmv_beep = df_rmv_beep[df_rmv_beep['Bot Transcription'] != i]
